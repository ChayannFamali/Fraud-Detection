# %%
import pandas as pd
data = pd.read_csv('../input/creditcardfraud/creditcard.csv')
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.473120e-16  8.042109e-16  5.282512e-16  4.456271e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   1.426896e-15  1.701640e-15 -3.662252e-16 -1.217809e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
data_df = data.copy()
data_df['Hour'] = data_df['Time'].apply(lambda x: np.floor(x / 3600))

tmp = data_df.groupby(['Hour', 'Class'])['Amount'].aggregate(['min', 'max', 'count', 'sum', 'mean', 'median', 'var']).reset_index()
df = pd.DataFrame(tmp)
df.columns = ['Hour', 'Class', 'Min', 'Max', 'Transactions', 'Sum', 'Mean', 'Median', 'Var']
df.head()
# Out:
#    Hour  Class   Min      Max  Transactions        Sum        Mean   Median  \
# 0   0.0      0   0.0  7712.43          3961  256572.87   64.774772   12.990
# 1   0.0      1   0.0   529.00             2     529.00  264.500000  264.500
# 2   1.0      0   0.0  1769.69          2215  145806.76   65.826980   22.820
# 3   1.0      1  59.0   239.93             2     298.93  149.465000  149.465
# 4   2.0      0   0.0  4002.88          1555  106989.39   68.803466   17.900
#
#              Var
# 0   45615.821201
# 1  139920.500000
# 2   20053.615770
# 3   16367.832450
# 4   45355.430437

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(18,6))
s = sns.lineplot(ax = ax1, x="Hour", y="Sum", data=df.loc[df.Class==0])
s = sns.lineplot(ax = ax2, x="Hour", y="Sum", data=df.loc[df.Class==1], color="red")
plt.suptitle("Total Amount")
plt.show();

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(18,6))
s = sns.lineplot(ax = ax1, x="Hour", y="Transactions", data=df.loc[df.Class==0])
s = sns.lineplot(ax = ax2, x="Hour", y="Transactions", data=df.loc[df.Class==1], color="red")
plt.suptitle("Total Number of Transactions")
plt.show();

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(18,6))
s = sns.lineplot(ax = ax1, x="Hour", y="Mean", data=df.loc[df.Class==0])
s = sns.lineplot(ax = ax2, x="Hour", y="Mean", data=df.loc[df.Class==1], color="red")
plt.suptitle("Average Amount of Transactions")
plt.show();

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(18,6))
s = sns.lineplot(ax = ax1, x="Hour", y="Max", data=df.loc[df.Class==0])
s = sns.lineplot(ax = ax2, x="Hour", y="Max", data=df.loc[df.Class==1], color="red")
plt.suptitle("Maximum Amount of Transactions")
plt.show();fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(18,6))
s = sns.lineplot(ax = ax1, x="Hour", y="Max", data=df.loc[df.Class==0])
s = sns.lineplot(ax = ax2, x="Hour", y="Max", data=df.loc[df.Class==1], color="red")
plt.suptitle("Maximum Amount of Transactions")
plt.show();

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(18,6))
s = sns.lineplot(ax = ax1, x="Hour", y="Median", data=df.loc[df.Class==0])
s = sns.lineplot(ax = ax2, x="Hour", y="Median", data=df.loc[df.Class==1], color="red")
plt.suptitle("Median Amount of Transactions")
plt.show();

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(18,6))
s = sns.lineplot(ax = ax1, x="Hour", y="Min", data=df.loc[df.Class==0])
s = sns.lineplot(ax = ax2, x="Hour", y="Min", data=df.loc[df.Class==1], color="red")
plt.suptitle("Minimum Amount of Transactions")
plt.show();

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,6))
s = sns.boxplot(ax = ax1, x="Class", y="Amount", hue="Class",data=data_df, palette="PRGn",showfliers=True)
s = sns.boxplot(ax = ax2, x="Class", y="Amount", hue="Class",data=data_df, palette="PRGn",showfliers=False)
plt.show();

# %%
plt.figure(figsize = (14,14))
plt.title('Credit Card Transactions features correlation plot (Pearson)')
corr = data_df.corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns,linewidths=.1,cmap="Reds")
plt.show()

# %%
s = sns.lmplot(x='V20', y='Amount',data=data_df, hue='Class', fit_reg=True,scatter_kws={'s':2})
s = sns.lmplot(x='V7', y='Amount',data=data_df, hue='Class', fit_reg=True,scatter_kws={'s':2})
plt.show()

# %%
s = sns.lmplot(x='V2', y='Amount',data=data_df, hue='Class', fit_reg=True,scatter_kws={'s':2})
s = sns.lmplot(x='V5', y='Amount',data=data_df, hue='Class', fit_reg=True,scatter_kws={'s':2})
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.set(style="darkgrid")
sns.countplot(data['Class'])
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
plt.figure(figsize=(15,7))
labels=['0','1']
colors = ["SkyBlue","PeachPuff"]
plt.pie(data['Class'].value_counts(),labels=labels,colors=colors,
        autopct='%1.2f%%', shadow=True, startangle=140) 
plt.show()

# %%
var = data_df.columns.values

i = 0
t0 = data_df.loc[data_df['Class'] == 0]
t1 = data_df.loc[data_df['Class'] == 1]

sns.set_style('whitegrid')
plt.figure()
fig, ax = plt.subplots(8,4,figsize=(16,28))

for feature in var:
    i += 1
    plt.subplot(8,4,i)
    sns.kdeplot(t0[feature], bw=0.5,label="Class = 0")
    sns.kdeplot(t1[feature], bw=0.5,label="Class = 1")
    plt.xlabel(feature, fontsize=12)
    locs, labels = plt.xticks()
    plt.tick_params(axis='both', which='major', labelsize=12)
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.5 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %%
X=data.drop('Class',axis=1)
y=data['Class']

# %%
from sklearn import preprocessing
norm = preprocessing.StandardScaler()
ndf=norm.fit_transform(X)
X = pd.DataFrame(ndf, index=X.index, columns=X.columns)
X.head(10)
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0 -1.996583 -0.694242 -0.044075  1.672773  0.973366 -0.245117  0.347068
# 1 -1.996583  0.608496  0.161176  0.109797  0.316523  0.043483 -0.061820
# 2 -1.996562 -0.693500 -0.811578  1.169468  0.268231 -0.364572  1.351454
# 3 -1.996562 -0.493325 -0.112169  1.182516 -0.609727 -0.007469  0.936150
# 4 -1.996541 -0.591330  0.531541  1.021412  0.284655 -0.295015  0.071999
# 5 -1.996541 -0.217475  0.581675  0.752585 -0.118833  0.305009 -0.022313
# 6 -1.996499  0.627795  0.085389  0.029923  0.849383  0.139020  0.204695
# 7 -1.996436 -0.328928  0.858692  0.708576 -0.347631  0.687512  0.321345
# 8 -1.996436 -0.456573  0.173291 -0.074653 -0.191774  1.934149  2.793594
# 9 -1.996394 -0.172698  0.678005  0.688781 -0.156927  0.361792 -0.185219
#
#          V7        V8        V9  ...       V20       V21       V22       V23  \
# 0  0.193679  0.082637  0.331128  ...  0.326118 -0.024923  0.382854 -0.176911
# 1 -0.063700  0.071253 -0.232494  ... -0.089611 -0.307377 -0.880077  0.162201
# 2  0.639776  0.207373 -1.378675  ...  0.680975  0.337632  1.063358  1.456320
# 3  0.192071  0.316018 -1.262503  ... -0.269855 -0.147443  0.007267 -0.304777
# 4  0.479302 -0.226510  0.744326  ...  0.529939 -0.012839  1.100011 -0.220123
# 5  0.384936  0.217955 -0.517619  ...  0.110215 -0.283522 -0.771427 -0.042273
# 6 -0.004170  0.067998  0.423218  ... -0.284895 -0.228334 -0.373032 -0.246780
# 7  0.905860 -3.188229  0.560129  ... -0.203317  2.645889 -1.399276  0.092085
# 8  0.299206  0.712592 -0.356851  ...  0.068406 -0.099963 -0.369425 -0.327055
# 9  0.526706  0.058223 -0.670587  ...  0.264243 -0.336156 -0.873298 -0.193438
#
#         V24       V25       V26       V27       V28    Amount
# 0  0.110507  0.246585 -0.392170  0.330892 -0.063781  0.244964
# 1 -0.561131  0.320694  0.261069 -0.022256  0.044608 -0.342475
# 2 -1.138092 -0.628537 -0.288447 -0.137137 -0.181021  1.160686
# 3 -1.941027  1.241904 -0.460217  0.155396  0.186189  0.140534
# 4  0.233250 -0.395202  1.041611  0.543620  0.651816 -0.073403
# 5 -0.613273 -0.446584  0.219637  0.628900  0.245636 -0.338556
# 6 -1.287973  1.439037 -0.533436  0.085492  0.015656 -0.333279
# 7 -1.072754 -0.796633 -0.107075 -2.990154 -3.288083 -0.190107
# 8  1.670269  0.715943 -0.796633  0.029104  0.431420  0.019392
# 9 -0.635767 -0.133773  0.195342  0.610010  0.251681 -0.338516
#
# [10 rows x 30 columns]

# %%
from imblearn.over_sampling import ADASYN 
X_resampled, y_resampled = ADASYN().fit_resample(X, y)

# %%
plt.figure(figsize=(15,7))
labels=['0','1']
colors = ["SkyBlue","PeachPuff"]
plt.pie(y_resampled.value_counts(),labels=labels,colors=colors,
        autopct='%1.2f%%', shadow=True, startangle=140) 
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test =train_test_split(X_resampled,y_resampled,train_size=0.7, random_state=42)

# %%
from sklearn.model_selection import RandomizedSearchCV
import lightgbm as lgb
params = {
    'learning_rate': [0.05,0.01,0.0001],
    'num_leaves': [90,140,200],
    'boosting_type' : ['gbdt'],
    'objective' : ['binary'],
    'max_depth' : [3,4,5,6,7,8],
    'random_state' : [42], 
    'colsample_bytree' : [0.5,0.6,0.7,0.8,1.0],
    'subsample' : [0.5,0.6,0.7,0.8,1.0],
    'min_split_gain' : [0.01],
    'min_data_in_leaf':[10],
    'metric':['auc']
    }
clf = lgb.LGBMClassifier()
RSCV = RandomizedSearchCV(clf,params,verbose=3,cv=10,n_jobs = -1,n_iter=10)
RSCV.fit(X_train,y_train)
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:  2.5min
# [CV] subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.0001, colsample_bytree=0.5, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.0001, colsample_bytree=0.5, boosting_type=gbdt, score=0.963, total=  10.5s
# [CV] subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.0001, colsample_bytree=0.5, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.0001, colsample_bytree=0.5, boosting_type=gbdt, score=0.964, total=   9.7s
# [CV] subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.0001, colsample_bytree=0.5, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.0001, colsample_bytree=0.5, boosting_type=gbdt, score=0.962, total=   9.7s
# [CV] subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.0001, colsample_bytree=0.5, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.0001, colsample_bytree=0.5, boosting_type=gbdt, score=0.962, total=  10.5s
# [CV] subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.0001, colsample_bytree=0.5, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.0001, colsample_bytree=0.5, boosting_type=gbdt, score=0.962, total=   9.8s
# [CV] subsample=1.0, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=1.0, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt, score=0.876, total=   8.3s
# [CV] subsample=1.0, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=1.0, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt, score=0.874, total=   8.6s
# [CV] subsample=1.0, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=1.0, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt, score=0.871, total=   9.3s
# [CV] subsample=1.0, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=1.0, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt, score=0.871, total=   8.6s
# [CV] subsample=1.0, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=1.0, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt, score=0.875, total=   8.7s
# [CV] subsample=0.5, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.01, colsample_bytree=0.6, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.5, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.01, colsample_bytree=0.6, boosting_type=gbdt, score=0.981, total=  12.3s
# [CV] subsample=0.5, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.01, colsample_bytree=0.6, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.5, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.01, colsample_bytree=0.6, boosting_type=gbdt, score=0.982, total=  11.7s
# [CV] subsample=0.5, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.01, colsample_bytree=0.6, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.5, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.01, colsample_bytree=0.6, boosting_type=gbdt, score=0.980, total=  11.7s
# [CV] subsample=0.5, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.01, colsample_bytree=0.6, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.5, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.01, colsample_bytree=0.6, boosting_type=gbdt, score=0.981, total=  13.0s
# [CV] subsample=0.5, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.01, colsample_bytree=0.6, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.5, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.01, colsample_bytree=0.6, boosting_type=gbdt, score=0.980, total=  12.0s[CV] subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.0001, colsample_bytree=0.5, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.0001, colsample_bytree=0.5, boosting_type=gbdt, score=0.960, total=  11.5s
# [CV] subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.0001, colsample_bytree=0.5, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.0001, colsample_bytree=0.5, boosting_type=gbdt, score=0.962, total=   9.7s
# [CV] subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.0001, colsample_bytree=0.5, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.0001, colsample_bytree=0.5, boosting_type=gbdt, score=0.962, total=   9.7s
# [CV] subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.0001, colsample_bytree=0.5, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.0001, colsample_bytree=0.5, boosting_type=gbdt, score=0.962, total=  10.6s
# [CV] subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.0001, colsample_bytree=0.5, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.0001, colsample_bytree=0.5, boosting_type=gbdt, score=0.961, total=   9.6s
# [CV] subsample=1.0, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=1.0, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt, score=0.870, total=   8.5s
# [CV] subsample=1.0, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=1.0, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt, score=0.873, total=   8.2s
# [CV] subsample=1.0, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=1.0, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt, score=0.872, total=   9.3s
# [CV] subsample=1.0, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=1.0, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt, score=0.873, total=   8.6s
# [CV] subsample=1.0, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=1.0, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt, score=0.874, total=   8.6s
# [CV] subsample=0.5, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.01, colsample_bytree=0.6, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.5, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.01, colsample_bytree=0.6, boosting_type=gbdt, score=0.980, total=  12.3s
# [CV] subsample=0.5, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.01, colsample_bytree=0.6, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.5, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.01, colsample_bytree=0.6, boosting_type=gbdt, score=0.982, total=  11.7s
# [CV] subsample=0.5, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.01, colsample_bytree=0.6, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.5, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.01, colsample_bytree=0.6, boosting_type=gbdt, score=0.979, total=  11.7s
# [CV] subsample=0.5, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.01, colsample_bytree=0.6, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.5, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.01, colsample_bytree=0.6, boosting_type=gbdt, score=0.981, total=  12.8s
# [CV] subsample=0.5, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.01, colsample_bytree=0.6, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.5, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.01, colsample_bytree=0.6, boosting_type=gbdt, score=0.981, total=  12.0s
# [CV] subsample=0.7, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.05, colsample_bytree=0.7, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.7, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.05, colsample_bytree=0.7, boosting_type=gbdt, score=0.943, total=   8.2s
# [CV] subsample=0.7, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.05, colsample_bytree=0.7, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.7, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.05, colsample_bytree=0.7, boosting_type=gbdt, score=0.941, total=   8.9s
# [CV] subsample=0.7, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.05, colsample_bytree=0.7, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.7, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.05, colsample_bytree=0.7, boosting_type=gbdt, score=0.940, total=   8.2s
# [CV] subsample=0.7, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.05, colsample_bytree=0.7, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.7, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.05, colsample_bytree=0.7, boosting_type=gbdt, score=0.942, total=   7.9s
# [CV] subsample=0.7, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.05, colsample_bytree=0.7, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.7, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.05, colsample_bytree=0.7, boosting_type=gbdt, score=0.942, total=   8.1s
# [CV] subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=5, learning_rate=0.0001, colsample_bytree=0.6, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=5, learning_rate=0.0001, colsample_bytree=0.6, boosting_type=gbdt, score=0.943, total=  10.2s
# [CV] subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=5, learning_rate=0.0001, colsample_bytree=0.6, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=5, learning_rate=0.0001, colsample_bytree=0.6, boosting_type=gbdt, score=0.941, total=  10.3s
# [CV] subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=5, learning_rate=0.0001, colsample_bytree=0.6, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=5, learning_rate=0.0001, colsample_bytree=0.6, boosting_type=gbdt, score=0.939, total=   9.6s
# [CV] subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=5, learning_rate=0.0001, colsample_bytree=0.6, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=5, learning_rate=0.0001, colsample_bytree=0.6, boosting_type=gbdt, score=0.939, total=  10.4s
# [CV] subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=5, learning_rate=0.0001, colsample_bytree=0.6, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=5, learning_rate=0.0001, colsample_bytree=0.6, boosting_type=gbdt, score=0.942, total=   9.2s
# [CV] subsample=0.6, random_state=42, objective=binary, num_leaves=90, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.01, colsample_bytree=0.5, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.6, random_state=42, objective=binary, num_leaves=90, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.01, colsample_bytree=0.5, boosting_type=gbdt, score=0.970, total=   9.8s
# [CV] subsample=0.6, random_state=42, objective=binary, num_leaves=90, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.01, colsample_bytree=0.5, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.6, random_state=42, objective=binary, num_leaves=90, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.01, colsample_bytree=0.5, boosting_type=gbdt, score=0.971, total=  10.5s
# [CV] subsample=0.6, random_state=42, objective=binary, num_leaves=90, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.01, colsample_bytree=0.5, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.6, random_state=42, objective=binary, num_leaves=90, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.01, colsample_bytree=0.5, boosting_type=gbdt, score=0.970, total=   9.9s
# [CV] subsample=0.6, random_state=42, objective=binary, num_leaves=90, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.01, colsample_bytree=0.5, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.6, random_state=42, objective=binary, num_leaves=90, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.01, colsample_bytree=0.5, boosting_type=gbdt, score=0.969, total=   9.9s
# [CV] subsample=0.6, random_state=42, objective=binary, num_leaves=90, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.01, colsample_bytree=0.5, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.6, random_state=42, objective=binary, num_leaves=90, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.01, colsample_bytree=0.5, boosting_type=gbdt, score=0.969, total=   9.8s
# [CV] subsample=0.7, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.05, colsample_bytree=0.7, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.7, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.05, colsample_bytree=0.7, boosting_type=gbdt, score=0.940, total=   8.2s
# [CV] subsample=0.7, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.05, colsample_bytree=0.7, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.7, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.05, colsample_bytree=0.7, boosting_type=gbdt, score=0.942, total=   8.8s
# [CV] subsample=0.7, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.05, colsample_bytree=0.7, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.7, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.05, colsample_bytree=0.7, boosting_type=gbdt, score=0.941, total=   8.6s
# [CV] subsample=0.7, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.05, colsample_bytree=0.7, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.7, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.05, colsample_bytree=0.7, boosting_type=gbdt, score=0.943, total=   7.6s
# [CV] subsample=0.7, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.05, colsample_bytree=0.7, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.7, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.05, colsample_bytree=0.7, boosting_type=gbdt, score=0.941, total=   8.0s
# [CV] subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=5, learning_rate=0.0001, colsample_bytree=0.6, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=5, learning_rate=0.0001, colsample_bytree=0.6, boosting_type=gbdt, score=0.938, total=  10.3s
# [CV] subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=5, learning_rate=0.0001, colsample_bytree=0.6, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=5, learning_rate=0.0001, colsample_bytree=0.6, boosting_type=gbdt, score=0.940, total=  10.3s
# [CV] subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=5, learning_rate=0.0001, colsample_bytree=0.6, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=5, learning_rate=0.0001, colsample_bytree=0.6, boosting_type=gbdt, score=0.940, total=   9.5s
# [CV] subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=5, learning_rate=0.0001, colsample_bytree=0.6, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=5, learning_rate=0.0001, colsample_bytree=0.6, boosting_type=gbdt, score=0.942, total=  10.3s
# [CV] subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=5, learning_rate=0.0001, colsample_bytree=0.6, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=5, learning_rate=0.0001, colsample_bytree=0.6, boosting_type=gbdt, score=0.941, total=   9.3s
# [CV] subsample=0.6, random_state=42, objective=binary, num_leaves=90, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.01, colsample_bytree=0.5, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.6, random_state=42, objective=binary, num_leaves=90, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.01, colsample_bytree=0.5, boosting_type=gbdt, score=0.968, total=   9.5s
# [CV] subsample=0.6, random_state=42, objective=binary, num_leaves=90, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.01, colsample_bytree=0.5, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.6, random_state=42, objective=binary, num_leaves=90, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.01, colsample_bytree=0.5, boosting_type=gbdt, score=0.971, total=  10.3s
# [CV] subsample=0.6, random_state=42, objective=binary, num_leaves=90, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.01, colsample_bytree=0.5, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.6, random_state=42, objective=binary, num_leaves=90, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.01, colsample_bytree=0.5, boosting_type=gbdt, score=0.969, total=   9.8s
# [CV] subsample=0.6, random_state=42, objective=binary, num_leaves=90, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.01, colsample_bytree=0.5, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.6, random_state=42, objective=binary, num_leaves=90, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.01, colsample_bytree=0.5, boosting_type=gbdt, score=0.970, total=  10.0s
# [CV] subsample=0.6, random_state=42, objective=binary, num_leaves=90, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.01, colsample_bytree=0.5, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.6, random_state=42, objective=binary, num_leaves=90, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=6, learning_rate=0.01, colsample_bytree=0.5, boosting_type=gbdt, score=0.971, total=   9.9s
# [CV] subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt, score=0.876, total=   9.1s
# [CV] subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt, score=0.874, total=   8.5s
# [CV] subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt, score=0.871, total=   8.2s
# [CV] subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt, score=0.871, total=   8.9s
# [CV] subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt, score=0.875, total=   8.7s
# [CV] subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.05, colsample_bytree=0.5, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.05, colsample_bytree=0.5, boosting_type=gbdt, score=0.996, total=  10.5s
# [CV] subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.05, colsample_bytree=0.5, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.05, colsample_bytree=0.5, boosting_type=gbdt, score=0.995, total=  10.6s
# [CV] subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.05, colsample_bytree=0.5, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.05, colsample_bytree=0.5, boosting_type=gbdt, score=0.995, total=  11.0s
# [CV] subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.05, colsample_bytree=0.5, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.05, colsample_bytree=0.5, boosting_type=gbdt, score=0.996, total=  10.5s
# [CV] subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.05, colsample_bytree=0.5, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.05, colsample_bytree=0.5, boosting_type=gbdt, score=0.995, total=  10.3s
# [CV] subsample=0.8, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.01, colsample_bytree=0.7, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.8, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.01, colsample_bytree=0.7, boosting_type=gbdt, score=0.897, total=   9.0s
# [CV] subsample=0.8, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.01, colsample_bytree=0.7, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.8, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.01, colsample_bytree=0.7, boosting_type=gbdt, score=0.894, total=   8.0s
# [CV] subsample=0.8, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.01, colsample_bytree=0.7, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.8, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.01, colsample_bytree=0.7, boosting_type=gbdt, score=0.895, total=   8.3s
# [CV] subsample=0.8, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.01, colsample_bytree=0.7, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.8, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.01, colsample_bytree=0.7, boosting_type=gbdt, score=0.894, total=   8.5s
# [CV] subsample=0.8, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.01, colsample_bytree=0.7, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.8, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.01, colsample_bytree=0.7, boosting_type=gbdt, score=0.900, total=   8.8s
# [CV] subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt, score=0.870, total=   9.3s
# [CV] subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt, score=0.873, total=   8.6s
# [CV] subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt, score=0.872, total=   8.2s
# [CV] subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt, score=0.873, total=   9.1s
# [CV] subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.5, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.0001, colsample_bytree=0.8, boosting_type=gbdt, score=0.874, total=   8.7s
# [CV] subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.05, colsample_bytree=0.5, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.05, colsample_bytree=0.5, boosting_type=gbdt, score=0.995, total=  11.4s
# [CV] subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.05, colsample_bytree=0.5, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.05, colsample_bytree=0.5, boosting_type=gbdt, score=0.995, total=  10.4s
# [CV] subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.05, colsample_bytree=0.5, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.05, colsample_bytree=0.5, boosting_type=gbdt, score=0.995, total=  11.1s
# [CV] subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.05, colsample_bytree=0.5, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.05, colsample_bytree=0.5, boosting_type=gbdt, score=0.996, total=  10.4s
# [CV] subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.05, colsample_bytree=0.5, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=1.0, random_state=42, objective=binary, num_leaves=200, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=7, learning_rate=0.05, colsample_bytree=0.5, boosting_type=gbdt, score=0.996, total=  10.5s
# [CV] subsample=0.8, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.01, colsample_bytree=0.7, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.8, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.01, colsample_bytree=0.7, boosting_type=gbdt, score=0.892, total=   8.9s
# [CV] subsample=0.8, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.01, colsample_bytree=0.7, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.8, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.01, colsample_bytree=0.7, boosting_type=gbdt, score=0.893, total=   7.9s
# [CV] subsample=0.8, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.01, colsample_bytree=0.7, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.8, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.01, colsample_bytree=0.7, boosting_type=gbdt, score=0.893, total=   8.2s
# [CV] subsample=0.8, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.01, colsample_bytree=0.7, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.8, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.01, colsample_bytree=0.7, boosting_type=gbdt, score=0.896, total=   8.8s
# [CV] subsample=0.8, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.01, colsample_bytree=0.7, boosting_type=gbdt
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [CV]  subsample=0.8, random_state=42, objective=binary, num_leaves=140, min_split_gain=0.01, min_data_in_leaf=10, metric=auc, max_depth=3, learning_rate=0.01, colsample_bytree=0.7, boosting_type=gbdt, score=0.895, total=   8.3s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  8.0min finished
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# RandomizedSearchCV(cv=10, estimator=LGBMClassifier(), n_jobs=-1,
#                    param_distributions={'boosting_type': ['gbdt'],
#                                         'colsample_bytree': [0.5, 0.6, 0.7, 0.8,
#                                                              1.0],
#                                         'learning_rate': [0.05, 0.01, 0.0001],
#                                         'max_depth': [3, 4, 5, 6, 7, 8],
#                                         'metric': ['auc'],
#                                         'min_data_in_leaf': [10],
#                                         'min_split_gain': [0.01],
#                                         'num_leaves': [90, 140, 200],
#                                         'objective': ['binary'],
#                                         'random_state': [42],
#                                         'subsample': [0.5, 0.6, 0.7, 0.8, 1.0]},
#                    verbose=3)

# %%
y_pred=RSCV.predict(X_test)
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     85164
#            1       0.99      1.00      1.00     85425
#
#     accuracy                           1.00    170589
#    macro avg       1.00      1.00      1.00    170589
# weighted avg       1.00      1.00      1.00    170589

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,y_pred)
# Out:
# 0.9951979497369307

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(RSCV,X_test,y_test)

# %%
RSCV.best_params_
# Out:
# {'subsample': 1.0,
#  'random_state': 42,
#  'objective': 'binary',
#  'num_leaves': 200,
#  'min_split_gain': 0.01,
#  'min_data_in_leaf': 10,
#  'metric': 'auc',
#  'max_depth': 7,
#  'learning_rate': 0.05,
#  'colsample_bytree': 0.5,
#  'boosting_type': 'gbdt'}

# %%
top_params = RSCV.best_params_
gbm_model = lgb.LGBMClassifier(subsample=1,random_state=42,objective='binary',
 num_leaves= 200,
 min_split_gain = 0.01,
 min_data_in_leaf = 10,
 metric = 'auc',
 max_depth = 7,
 learning_rate = 0.05,
 colsample_bytree = 0.5,
 boosting_type = 'gbdt')
gbm_model.fit(X_train, y_train)
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# array([259, 507, 271, 463, 659, 390, 259, 408, 372, 355, 417, 308, 354,
#        286, 528, 465, 499, 530, 355, 318, 291, 267, 234, 219, 193, 326,
#        326, 192, 207, 313], dtype=int32)

# %%
def plot_feature_importance(importance,names,model_type):
    feature_importance = np.array(importance)
    feature_names = np.array(names)
    data={'feature_names':feature_names,'feature_importance':feature_importance}
    fi_df = pd.DataFrame(data)
    fi_df.sort_values(by=['feature_importance'], ascending=False,inplace=True)
    plt.figure(figsize=(15,8))
    sns.barplot(x=fi_df['feature_importance'], y=fi_df['feature_names'])
    plt.title('FEATURE IMPORTANCE')
    plt.xlabel('FEATURE IMPORTANCE')
    plt.ylabel('FEATURE NAMES')

# %%
plot_feature_importance(gbm_model.feature_importances_,X_train.columns,'LightGBM')

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold
xgb = XGBClassifier(learning_rate=0.005,n_estimators=1000,seed=2022,reg_alpha=5,eval_metric='auc',tree_method='gpu_hist',
                    objective='binary:logistic',
                    silent=True, nthread=-1)
params = {
        'min_child_weight': [1, 5, 10],
        'gamma': [0.5, 1, 1.5, 2, 5],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [3, 4, 5]
        }
folds = 3
param_comb = 5

skf = StratifiedKFold(n_splits=folds, shuffle = True, random_state = 1001)

random_search = RandomizedSearchCV(xgb, param_distributions=params, n_iter=param_comb, scoring='roc_auc', n_jobs=-1, cv=skf.split(X_train,y_train), verbose=3, random_state=1001 )
random_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:  1.2min finished
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [17:14:35] WARNING: ../src/learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# RandomizedSearchCV(cv=<generator object _BaseKFold.split at 0x7ff879fb60d0>,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None,
#                                            enable_categorical=False,
#                                            eval_metric='auc', gamma=None,
#                                            gpu_id=None, importance_type=None,
#                                            interaction_constraints=None,
#                                            learning_rate=0.005,
#                                            max_delta_step=None, ma...
#                                            predictor=None, random_state=None,
#                                            reg_alpha=5, reg_lambda=None,
#                                            scale_pos_weight=None, seed=2022,
#                                            silent=True, subsample=None,
#                                            tree_method='gpu_hist', ...),
#                    n_iter=5, n_jobs=-1,
#                    param_distributions={'colsample_bytree': [0.6, 0.8, 1.0],
#                                         'gamma': [0.5, 1, 1.5, 2, 5],
#                                         'max_depth': [3, 4, 5],
#                                         'min_child_weight': [1, 5, 10],
#                                         'subsample': [0.6, 0.8, 1.0]},
#                    random_state=1001, scoring='roc_auc', verbose=3)

# %%
from sklearn.ensemble import RandomForestClassifier

y_predict = random_search.predict(X_test)

print(classification_report(y_test, y_predict))

plot_confusion_matrix(random_search,X_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98     85164
#            1       0.97      0.99      0.98     85425
#
#     accuracy                           0.98    170589
#    macro avg       0.98      0.98      0.98    170589
# weighted avg       0.98      0.98      0.98    170589

# %%
print(roc_auc_score(y_test,y_predict))
# Out:
# 0.9830424770691875

# %%
random_search.best_params_
# Out:
# {'subsample': 1.0,
#  'min_child_weight': 5,
#  'max_depth': 5,
#  'gamma': 5,
#  'colsample_bytree': 0.6}

# %%
xgb = XGBClassifier(learning_rate=0.005,n_estimators=1000,seed=2022,reg_alpha=5,eval_metric='auc',tree_method='gpu_hist',
                    objective='binary:logistic',subsample=1,min_child_weight=5,max_depth=5,gamma=5,colsample_bytree=0.6,
                    silent=True, nthread=-1)
xgb.fit(X_train, y_train)
# Out:
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [17:16:48] WARNING: ../src/learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.6,
#               enable_categorical=False, eval_metric='auc', gamma=5, gpu_id=0,
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.005, max_delta_step=0, max_depth=5,
#               min_child_weight=5, missing=nan, monotone_constraints='()',
#               n_estimators=1000, n_jobs=2, nthread=-1, num_parallel_tree=1,
#               predictor='auto', random_state=2022, reg_alpha=5, reg_lambda=1,
#               scale_pos_weight=1, seed=2022, silent=True, subsample=1,
#               tree_method='gpu_hist', ...)

# %%
plot_feature_importance(xgb.feature_importances_,X_train.columns,'XGBOOST')

# %%
from catboost import CatBoostClassifier
catboost_params = {'loss_function' : 'CrossEntropy',
            'iterations': 2000,
            'depth': 5,
            'learning_rate': 0.01,
            'eval_metric': 'AUC',
            'random_seed': 4,
            'l2_leaf_reg': 15.0,
            'bagging_temperature': 0.75,
            'allow_writing_files': False, 'border_count':50
        }
model = CatBoostClassifier(**catboost_params)
model.fit(X_train, y_train,verbose=True)
# Out:
# 0:	total: 150ms	remaining: 4m 59s
# 1:	total: 238ms	remaining: 3m 57s
# 2:	total: 329ms	remaining: 3m 38s
# 3:	total: 417ms	remaining: 3m 28s
# 4:	total: 503ms	remaining: 3m 20s
# 5:	total: 591ms	remaining: 3m 16s
# 6:	total: 673ms	remaining: 3m 11s
# 7:	total: 755ms	remaining: 3m 8s
# 8:	total: 837ms	remaining: 3m 5s
# 9:	total: 928ms	remaining: 3m 4s
# 10:	total: 1.01s	remaining: 3m 2s
# 11:	total: 1.09s	remaining: 3m
# 12:	total: 1.17s	remaining: 2m 59s
# 13:	total: 1.26s	remaining: 2m 58s
# 14:	total: 1.35s	remaining: 2m 58s
# 15:	total: 1.43s	remaining: 2m 57s
# 16:	total: 1.52s	remaining: 2m 57s
# 17:	total: 1.6s	remaining: 2m 56s
# 18:	total: 1.69s	remaining: 2m 55s
# 19:	total: 1.77s	remaining: 2m 55s
# 20:	total: 1.85s	remaining: 2m 54s
# 21:	total: 1.94s	remaining: 2m 53s
# 22:	total: 2.02s	remaining: 2m 53s
# 23:	total: 2.1s	remaining: 2m 53s
# 24:	total: 2.19s	remaining: 2m 53s
# 25:	total: 2.28s	remaining: 2m 52s
# 26:	total: 2.36s	remaining: 2m 52s
# 27:	total: 2.44s	remaining: 2m 52s
# 28:	total: 2.52s	remaining: 2m 51s
# 29:	total: 2.61s	remaining: 2m 51s
# 30:	total: 2.69s	remaining: 2m 51s
# 31:	total: 2.78s	remaining: 2m 50s
# 32:	total: 2.87s	remaining: 2m 50s
# 33:	total: 2.96s	remaining: 2m 51s
# 34:	total: 3.04s	remaining: 2m 50s
# 35:	total: 3.12s	remaining: 2m 50s
# 36:	total: 3.21s	remaining: 2m 50s
# 37:	total: 3.29s	remaining: 2m 49s
# 38:	total: 3.37s	remaining: 2m 49s
# 39:	total: 3.46s	remaining: 2m 49s
# 40:	total: 3.54s	remaining: 2m 49s
# 41:	total: 3.63s	remaining: 2m 49s
# 42:	total: 3.72s	remaining: 2m 49s
# 43:	total: 3.8s	remaining: 2m 49s
# 44:	total: 3.89s	remaining: 2m 49s
# 45:	total: 3.98s	remaining: 2m 49s
# 46:	total: 4.07s	remaining: 2m 49s
# 47:	total: 4.17s	remaining: 2m 49s
# 48:	total: 4.26s	remaining: 2m 49s
# 49:	total: 4.35s	remaining: 2m 49s
# 50:	total: 4.44s	remaining: 2m 49s
# 51:	total: 4.53s	remaining: 2m 49s
# 52:	total: 4.62s	remaining: 2m 49s
# 53:	total: 4.7s	remaining: 2m 49s
# 54:	total: 4.79s	remaining: 2m 49s
# 55:	total: 4.87s	remaining: 2m 49s
# 56:	total: 4.96s	remaining: 2m 49s
# 57:	total: 5.04s	remaining: 2m 48s
# 58:	total: 5.13s	remaining: 2m 48s
# 59:	total: 5.21s	remaining: 2m 48s
# 60:	total: 5.3s	remaining: 2m 48s
# 61:	total: 5.39s	remaining: 2m 48s
# 62:	total: 5.48s	remaining: 2m 48s
# 63:	total: 5.57s	remaining: 2m 48s
# 64:	total: 5.66s	remaining: 2m 48s
# 65:	total: 5.75s	remaining: 2m 48s
# 66:	total: 5.83s	remaining: 2m 48s
# 67:	total: 5.92s	remaining: 2m 48s
# 68:	total: 6.01s	remaining: 2m 48s
# 69:	total: 6.09s	remaining: 2m 47s
# 70:	total: 6.25s	remaining: 2m 49s
# 71:	total: 6.43s	remaining: 2m 52s
# 72:	total: 6.61s	remaining: 2m 54s
# 73:	total: 6.77s	remaining: 2m 56s
# 74:	total: 6.86s	remaining: 2m 55s
# 75:	total: 6.94s	remaining: 2m 55s
# 76:	total: 7.02s	remaining: 2m 55s
# 77:	total: 7.1s	remaining: 2m 55s
# 78:	total: 7.19s	remaining: 2m 54s
# 79:	total: 7.28s	remaining: 2m 54s
# 80:	total: 7.37s	remaining: 2m 54s
# 81:	total: 7.46s	remaining: 2m 54s
# 82:	total: 7.54s	remaining: 2m 54s
# 83:	total: 7.62s	remaining: 2m 53s
# 84:	total: 7.7s	remaining: 2m 53s
# 85:	total: 7.79s	remaining: 2m 53s
# 86:	total: 7.88s	remaining: 2m 53s
# 87:	total: 7.97s	remaining: 2m 53s
# 88:	total: 8.06s	remaining: 2m 53s
# 89:	total: 8.14s	remaining: 2m 52s
# 90:	total: 8.22s	remaining: 2m 52s
# 91:	total: 8.31s	remaining: 2m 52s
# 92:	total: 8.4s	remaining: 2m 52s
# 93:	total: 8.49s	remaining: 2m 52s
# 94:	total: 8.57s	remaining: 2m 51s
# 95:	total: 8.66s	remaining: 2m 51s
# 96:	total: 8.74s	remaining: 2m 51s
# 97:	total: 8.83s	remaining: 2m 51s
# 98:	total: 8.91s	remaining: 2m 51s
# 99:	total: 9s	remaining: 2m 51s
# 100:	total: 9.09s	remaining: 2m 50s
# 101:	total: 9.18s	remaining: 2m 50s
# 102:	total: 9.26s	remaining: 2m 50s
# 103:	total: 9.35s	remaining: 2m 50s
# 104:	total: 9.43s	remaining: 2m 50s
# 105:	total: 9.51s	remaining: 2m 49s
# 106:	total: 9.6s	remaining: 2m 49s
# 107:	total: 9.67s	remaining: 2m 49s
# 108:	total: 9.76s	remaining: 2m 49s
# 109:	total: 9.85s	remaining: 2m 49s
# 110:	total: 9.92s	remaining: 2m 48s
# 111:	total: 10s	remaining: 2m 48s
# 112:	total: 10.1s	remaining: 2m 48s
# 113:	total: 10.2s	remaining: 2m 48s
# 114:	total: 10.3s	remaining: 2m 48s
# 115:	total: 10.4s	remaining: 2m 48s
# 116:	total: 10.4s	remaining: 2m 48s
# 117:	total: 10.5s	remaining: 2m 47s
# 118:	total: 10.6s	remaining: 2m 47s
# 119:	total: 10.7s	remaining: 2m 47s
# 120:	total: 10.8s	remaining: 2m 47s
# 121:	total: 10.9s	remaining: 2m 47s
# 122:	total: 10.9s	remaining: 2m 46s
# 123:	total: 11s	remaining: 2m 46s
# 124:	total: 11.1s	remaining: 2m 46s
# 125:	total: 11.2s	remaining: 2m 46s
# 126:	total: 11.3s	remaining: 2m 46s
# 127:	total: 11.4s	remaining: 2m 46s
# 128:	total: 11.4s	remaining: 2m 45s
# 129:	total: 11.5s	remaining: 2m 45s
# 130:	total: 11.6s	remaining: 2m 45s
# 131:	total: 11.7s	remaining: 2m 45s
# 132:	total: 11.8s	remaining: 2m 45s
# 133:	total: 11.8s	remaining: 2m 44s
# 134:	total: 11.9s	remaining: 2m 44s
# 135:	total: 12s	remaining: 2m 44s
# 136:	total: 12.1s	remaining: 2m 44s
# 137:	total: 12.2s	remaining: 2m 44s
# 138:	total: 12.3s	remaining: 2m 44s
# 139:	total: 12.4s	remaining: 2m 44s
# 140:	total: 12.4s	remaining: 2m 43s
# 141:	total: 12.5s	remaining: 2m 43s
# 142:	total: 12.6s	remaining: 2m 43s
# 143:	total: 12.7s	remaining: 2m 43s
# 144:	total: 12.8s	remaining: 2m 43s
# 145:	total: 12.9s	remaining: 2m 43s
# 146:	total: 13s	remaining: 2m 43s
# 147:	total: 13s	remaining: 2m 43s
# 148:	total: 13.1s	remaining: 2m 43s
# 149:	total: 13.2s	remaining: 2m 42s
# 150:	total: 13.3s	remaining: 2m 42s
# 151:	total: 13.4s	remaining: 2m 42s
# 152:	total: 13.5s	remaining: 2m 42s
# 153:	total: 13.5s	remaining: 2m 42s
# 154:	total: 13.6s	remaining: 2m 42s
# 155:	total: 13.7s	remaining: 2m 41s
# 156:	total: 13.8s	remaining: 2m 41s
# 157:	total: 13.9s	remaining: 2m 41s
# 158:	total: 13.9s	remaining: 2m 41s
# 159:	total: 14s	remaining: 2m 41s
# 160:	total: 14.1s	remaining: 2m 41s
# 161:	total: 14.2s	remaining: 2m 41s
# 162:	total: 14.3s	remaining: 2m 41s
# 163:	total: 14.4s	remaining: 2m 41s
# 164:	total: 14.5s	remaining: 2m 41s
# 165:	total: 14.6s	remaining: 2m 40s
# 166:	total: 14.6s	remaining: 2m 40s
# 167:	total: 14.7s	remaining: 2m 40s
# 168:	total: 14.8s	remaining: 2m 40s
# 169:	total: 14.9s	remaining: 2m 40s
# 170:	total: 15s	remaining: 2m 40s
# 171:	total: 15.1s	remaining: 2m 39s
# 172:	total: 15.1s	remaining: 2m 39s
# 173:	total: 15.2s	remaining: 2m 39s
# 174:	total: 15.3s	remaining: 2m 39s
# 175:	total: 15.4s	remaining: 2m 39s
# 176:	total: 15.5s	remaining: 2m 39s
# 177:	total: 15.6s	remaining: 2m 39s
# 178:	total: 15.6s	remaining: 2m 39s
# 179:	total: 15.7s	remaining: 2m 38s
# 180:	total: 15.8s	remaining: 2m 38s
# 181:	total: 15.9s	remaining: 2m 38s
# 182:	total: 16s	remaining: 2m 38s
# 183:	total: 16s	remaining: 2m 38s
# 184:	total: 16.1s	remaining: 2m 38s
# 185:	total: 16.2s	remaining: 2m 38s
# 186:	total: 16.3s	remaining: 2m 37s
# 187:	total: 16.4s	remaining: 2m 37s
# 188:	total: 16.5s	remaining: 2m 37s
# 189:	total: 16.5s	remaining: 2m 37s
# 190:	total: 16.6s	remaining: 2m 37s
# 191:	total: 16.7s	remaining: 2m 37s
# 192:	total: 16.8s	remaining: 2m 37s
# 193:	total: 16.9s	remaining: 2m 37s
# 194:	total: 17s	remaining: 2m 37s
# 195:	total: 17s	remaining: 2m 36s
# 196:	total: 17.2s	remaining: 2m 37s
# 197:	total: 17.4s	remaining: 2m 38s
# 198:	total: 17.5s	remaining: 2m 38s
# [CV] subsample=1.0, min_child_weight=5, max_depth=3, gamma=5, colsample_bytree=1.0
# [17:13:28] WARNING: ../src/learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV]  subsample=1.0, min_child_weight=5, max_depth=3, gamma=5, colsample_bytree=1.0, score=0.987, total=  11.7s
# [CV] subsample=0.6, min_child_weight=1, max_depth=5, gamma=1.5, colsample_bytree=0.8
# [17:13:36] WARNING: ../src/learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV]  subsample=0.6, min_child_weight=1, max_depth=5, gamma=1.5, colsample_bytree=0.8, score=0.998, total=  11.1s
# [CV] subsample=0.6, min_child_weight=1, max_depth=5, gamma=1.5, colsample_bytree=0.8
# [17:13:47] WARNING: ../src/learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV]  subsample=0.6, min_child_weight=1, max_depth=5, gamma=1.5, colsample_bytree=0.8, score=0.998, total=   9.5s
# [CV] subsample=0.8, min_child_weight=5, max_depth=5, gamma=1, colsample_bytree=0.8
# [17:13:56] WARNING: ../src/learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV]  subsample=0.8, min_child_weight=5, max_depth=5, gamma=1, colsample_bytree=0.8, score=0.998, total=   9.6s
# [CV] subsample=1.0, min_child_weight=5, max_depth=5, gamma=5, colsample_bytree=0.6
# [17:14:06] WARNING: ../src/learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV]  subsample=1.0, min_child_weight=5, max_depth=5, gamma=5, colsample_bytree=0.6, score=0.998, total=  10.2s
# [CV] subsample=1.0, min_child_weight=5, max_depth=5, gamma=5, colsample_bytree=0.6
# [17:14:16] WARNING: ../src/learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV]  subsample=1.0, min_child_weight=5, max_depth=5, gamma=5, colsample_bytree=0.6, score=0.998, total=   9.7s
# [CV] subsample=0.8, min_child_weight=1, max_depth=4, gamma=1, colsample_bytree=1.0
# [17:14:26] WARNING: ../src/learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV]  subsample=0.8, min_child_weight=1, max_depth=4, gamma=1, colsample_bytree=1.0, score=0.994, total=   7.2s
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# 199:	total: 17.8s	remaining: 2m 39s
# 200:	total: 17.9s	remaining: 2m 40s
# 201:	total: 18.1s	remaining: 2m 41s
# 202:	total: 18.3s	remaining: 2m 41s
# 203:	total: 18.4s	remaining: 2m 41s
# 204:	total: 18.6s	remaining: 2m 42s
# 205:	total: 18.8s	remaining: 2m 43s
# 206:	total: 18.9s	remaining: 2m 44s
# [CV] subsample=1.0, min_child_weight=5, max_depth=3, gamma=5, colsample_bytree=1.0
# [17:13:28] WARNING: ../src/learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV]  subsample=1.0, min_child_weight=5, max_depth=3, gamma=5, colsample_bytree=1.0, score=0.987, total=  11.6s
# [CV] subsample=1.0, min_child_weight=5, max_depth=3, gamma=5, colsample_bytree=1.0
# [17:13:36] WARNING: ../src/learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV]  subsample=1.0, min_child_weight=5, max_depth=3, gamma=5, colsample_bytree=1.0, score=0.986, total=   7.0s
# [CV] subsample=0.6, min_child_weight=1, max_depth=5, gamma=1.5, colsample_bytree=0.8
# [17:13:43] WARNING: ../src/learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV]  subsample=0.6, min_child_weight=1, max_depth=5, gamma=1.5, colsample_bytree=0.8, score=0.998, total=  10.2s
# [CV] subsample=0.8, min_child_weight=5, max_depth=5, gamma=1, colsample_bytree=0.8
# [17:13:53] WARNING: ../src/learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV]  subsample=0.8, min_child_weight=5, max_depth=5, gamma=1, colsample_bytree=0.8, score=0.998, total=   9.1s
# [CV] subsample=0.8, min_child_weight=5, max_depth=5, gamma=1, colsample_bytree=0.8
# [17:14:02] WARNING: ../src/learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV]  subsample=0.8, min_child_weight=5, max_depth=5, gamma=1, colsample_bytree=0.8, score=0.998, total=   9.7s
# [CV] subsample=1.0, min_child_weight=5, max_depth=5, gamma=5, colsample_bytree=0.6
# [17:14:12] WARNING: ../src/learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV]  subsample=1.0, min_child_weight=5, max_depth=5, gamma=5, colsample_bytree=0.6, score=0.998, total=   9.2s
# [CV] subsample=0.8, min_child_weight=1, max_depth=4, gamma=1, colsample_bytree=1.0
# [17:14:21] WARNING: ../src/learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV]  subsample=0.8, min_child_weight=1, max_depth=4, gamma=1, colsample_bytree=1.0, score=0.994, total=   7.4s
# [CV] subsample=0.8, min_child_weight=1, max_depth=4, gamma=1, colsample_bytree=1.0
# [17:14:28] WARNING: ../src/learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV]  subsample=0.8, min_child_weight=1, max_depth=4, gamma=1, colsample_bytree=1.0, score=0.994, total=   6.5s
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# 207:	total: 19.2s	remaining: 2m 45s
# 208:	total: 19.5s	remaining: 2m 46s
# 209:	total: 19.7s	remaining: 2m 48s
# 210:	total: 19.9s	remaining: 2m 48s
# 211:	total: 20s	remaining: 2m 48s
# 212:	total: 20.1s	remaining: 2m 48s
# 213:	total: 20.2s	remaining: 2m 48s
# 214:	total: 20.2s	remaining: 2m 47s
# 215:	total: 20.3s	remaining: 2m 47s
# 216:	total: 20.4s	remaining: 2m 47s
# 217:	total: 20.5s	remaining: 2m 47s
# 218:	total: 20.6s	remaining: 2m 47s
# 219:	total: 20.6s	remaining: 2m 47s
# 220:	total: 20.7s	remaining: 2m 46s
# 221:	total: 20.8s	remaining: 2m 46s
# 222:	total: 20.9s	remaining: 2m 46s
# 223:	total: 21s	remaining: 2m 46s
# 224:	total: 21.1s	remaining: 2m 46s
# 225:	total: 21.1s	remaining: 2m 45s
# 226:	total: 21.2s	remaining: 2m 45s
# 227:	total: 21.3s	remaining: 2m 45s
# 228:	total: 21.4s	remaining: 2m 45s
# 229:	total: 21.5s	remaining: 2m 45s
# 230:	total: 21.5s	remaining: 2m 44s
# 231:	total: 21.6s	remaining: 2m 44s
# 232:	total: 21.7s	remaining: 2m 44s
# 233:	total: 21.8s	remaining: 2m 44s
# 234:	total: 21.9s	remaining: 2m 44s
# 235:	total: 21.9s	remaining: 2m 44s
# 236:	total: 22s	remaining: 2m 43s
# 237:	total: 22.1s	remaining: 2m 43s
# 238:	total: 22.2s	remaining: 2m 43s
# 239:	total: 22.3s	remaining: 2m 43s
# 240:	total: 22.4s	remaining: 2m 43s
# 241:	total: 22.4s	remaining: 2m 43s
# 242:	total: 22.5s	remaining: 2m 42s
# 243:	total: 22.6s	remaining: 2m 42s
# 244:	total: 22.7s	remaining: 2m 42s
# 245:	total: 22.8s	remaining: 2m 42s
# 246:	total: 22.8s	remaining: 2m 42s
# 247:	total: 22.9s	remaining: 2m 41s
# 248:	total: 23s	remaining: 2m 41s
# 249:	total: 23.1s	remaining: 2m 41s
# 250:	total: 23.2s	remaining: 2m 41s
# 251:	total: 23.2s	remaining: 2m 41s
# 252:	total: 23.3s	remaining: 2m 40s
# 253:	total: 23.4s	remaining: 2m 40s
# 254:	total: 23.5s	remaining: 2m 40s
# 255:	total: 23.6s	remaining: 2m 40s
# 256:	total: 23.6s	remaining: 2m 40s
# 257:	total: 23.7s	remaining: 2m 40s
# 258:	total: 23.8s	remaining: 2m 40s
# 259:	total: 23.9s	remaining: 2m 39s
# 260:	total: 24s	remaining: 2m 39s
# 261:	total: 24s	remaining: 2m 39s
# 262:	total: 24.1s	remaining: 2m 39s
# 263:	total: 24.2s	remaining: 2m 39s
# 264:	total: 24.3s	remaining: 2m 39s
# 265:	total: 24.4s	remaining: 2m 38s
# 266:	total: 24.5s	remaining: 2m 38s
# 267:	total: 24.6s	remaining: 2m 38s
# 268:	total: 24.6s	remaining: 2m 38s
# 269:	total: 24.7s	remaining: 2m 38s
# 270:	total: 24.8s	remaining: 2m 38s
# 271:	total: 24.9s	remaining: 2m 38s
# 272:	total: 25s	remaining: 2m 37s
# 273:	total: 25s	remaining: 2m 37s
# 274:	total: 25.1s	remaining: 2m 37s
# 275:	total: 25.2s	remaining: 2m 37s
# 276:	total: 25.3s	remaining: 2m 37s
# 277:	total: 25.4s	remaining: 2m 37s
# 278:	total: 25.5s	remaining: 2m 37s
# 279:	total: 25.5s	remaining: 2m 36s
# 280:	total: 25.6s	remaining: 2m 36s
# 281:	total: 25.7s	remaining: 2m 36s
# 282:	total: 25.8s	remaining: 2m 36s
# 283:	total: 25.9s	remaining: 2m 36s
# 284:	total: 25.9s	remaining: 2m 36s
# 285:	total: 26s	remaining: 2m 35s
# 286:	total: 26.1s	remaining: 2m 35s
# 287:	total: 26.2s	remaining: 2m 35s
# 288:	total: 26.2s	remaining: 2m 35s
# 289:	total: 26.3s	remaining: 2m 35s
# 290:	total: 26.4s	remaining: 2m 35s
# 291:	total: 26.5s	remaining: 2m 34s
# 292:	total: 26.6s	remaining: 2m 34s
# 293:	total: 26.6s	remaining: 2m 34s
# 294:	total: 26.7s	remaining: 2m 34s
# 295:	total: 26.8s	remaining: 2m 34s
# 296:	total: 26.9s	remaining: 2m 34s
# 297:	total: 27s	remaining: 2m 34s
# 298:	total: 27s	remaining: 2m 33s
# 299:	total: 27.1s	remaining: 2m 33s
# 300:	total: 27.2s	remaining: 2m 33s
# 301:	total: 27.3s	remaining: 2m 33s
# 302:	total: 27.4s	remaining: 2m 33s
# 303:	total: 27.4s	remaining: 2m 33s
# 304:	total: 27.5s	remaining: 2m 32s
# 305:	total: 27.6s	remaining: 2m 32s
# 306:	total: 27.7s	remaining: 2m 32s
# 307:	total: 27.8s	remaining: 2m 32s
# 308:	total: 27.8s	remaining: 2m 32s
# 309:	total: 27.9s	remaining: 2m 32s
# 310:	total: 28s	remaining: 2m 32s
# 311:	total: 28.1s	remaining: 2m 32s
# 312:	total: 28.3s	remaining: 2m 32s
# 313:	total: 28.4s	remaining: 2m 32s
# 314:	total: 28.6s	remaining: 2m 32s
# 315:	total: 28.7s	remaining: 2m 33s
# 316:	total: 28.8s	remaining: 2m 33s
# 317:	total: 28.9s	remaining: 2m 32s
# 318:	total: 29s	remaining: 2m 32s
# 319:	total: 29.1s	remaining: 2m 32s
# 320:	total: 29.2s	remaining: 2m 32s
# 321:	total: 29.2s	remaining: 2m 32s
# 322:	total: 29.3s	remaining: 2m 32s
# 323:	total: 29.4s	remaining: 2m 32s
# 324:	total: 29.5s	remaining: 2m 31s
# 325:	total: 29.5s	remaining: 2m 31s
# 326:	total: 29.6s	remaining: 2m 31s
# 327:	total: 29.7s	remaining: 2m 31s
# 328:	total: 29.8s	remaining: 2m 31s
# 329:	total: 29.9s	remaining: 2m 31s
# 330:	total: 30s	remaining: 2m 31s
# 331:	total: 30s	remaining: 2m 30s
# 332:	total: 30.1s	remaining: 2m 30s
# 333:	total: 30.2s	remaining: 2m 30s
# 334:	total: 30.3s	remaining: 2m 30s
# 335:	total: 30.3s	remaining: 2m 30s
# 336:	total: 30.4s	remaining: 2m 30s
# 337:	total: 30.5s	remaining: 2m 30s
# 338:	total: 30.6s	remaining: 2m 29s
# 339:	total: 30.7s	remaining: 2m 29s
# 340:	total: 30.8s	remaining: 2m 29s
# 341:	total: 30.8s	remaining: 2m 29s
# 342:	total: 30.9s	remaining: 2m 29s
# 343:	total: 31s	remaining: 2m 29s
# 344:	total: 31.1s	remaining: 2m 29s
# 345:	total: 31.1s	remaining: 2m 28s
# 346:	total: 31.2s	remaining: 2m 28s
# 347:	total: 31.3s	remaining: 2m 28s
# 348:	total: 31.4s	remaining: 2m 28s
# 349:	total: 31.5s	remaining: 2m 28s
# 350:	total: 31.5s	remaining: 2m 28s
# 351:	total: 31.6s	remaining: 2m 27s
# 352:	total: 31.7s	remaining: 2m 27s
# 353:	total: 31.8s	remaining: 2m 27s
# 354:	total: 31.9s	remaining: 2m 27s
# 355:	total: 31.9s	remaining: 2m 27s
# 356:	total: 32s	remaining: 2m 27s
# 357:	total: 32.1s	remaining: 2m 27s
# 358:	total: 32.2s	remaining: 2m 27s
# 359:	total: 32.3s	remaining: 2m 26s
# 360:	total: 32.3s	remaining: 2m 26s
# 361:	total: 32.4s	remaining: 2m 26s
# 362:	total: 32.5s	remaining: 2m 26s
# 363:	total: 32.6s	remaining: 2m 26s
# 364:	total: 32.7s	remaining: 2m 26s
# 365:	total: 32.8s	remaining: 2m 26s
# 366:	total: 32.8s	remaining: 2m 26s
# 367:	total: 32.9s	remaining: 2m 26s
# 368:	total: 33s	remaining: 2m 25s
# 369:	total: 33.1s	remaining: 2m 25s
# 370:	total: 33.2s	remaining: 2m 25s
# 371:	total: 33.2s	remaining: 2m 25s
# 372:	total: 33.3s	remaining: 2m 25s
# 373:	total: 33.4s	remaining: 2m 25s
# 374:	total: 33.5s	remaining: 2m 25s
# 375:	total: 33.6s	remaining: 2m 24s
# 376:	total: 33.6s	remaining: 2m 24s
# 377:	total: 33.7s	remaining: 2m 24s
# 378:	total: 33.8s	remaining: 2m 24s
# 379:	total: 33.9s	remaining: 2m 24s
# 380:	total: 34s	remaining: 2m 24s
# 381:	total: 34s	remaining: 2m 24s
# 382:	total: 34.1s	remaining: 2m 24s
# 383:	total: 34.2s	remaining: 2m 24s
# 384:	total: 34.3s	remaining: 2m 23s
# 385:	total: 34.4s	remaining: 2m 23s
# 386:	total: 34.5s	remaining: 2m 23s
# 387:	total: 34.5s	remaining: 2m 23s
# 388:	total: 34.6s	remaining: 2m 23s
# 389:	total: 34.7s	remaining: 2m 23s
# 390:	total: 34.8s	remaining: 2m 23s
# 391:	total: 34.9s	remaining: 2m 23s
# 392:	total: 34.9s	remaining: 2m 22s
# 393:	total: 35s	remaining: 2m 22s
# 394:	total: 35.1s	remaining: 2m 22s
# 395:	total: 35.2s	remaining: 2m 22s
# 396:	total: 35.3s	remaining: 2m 22s
# 397:	total: 35.3s	remaining: 2m 22s
# 398:	total: 35.4s	remaining: 2m 22s
# 399:	total: 35.5s	remaining: 2m 21s
# 400:	total: 35.6s	remaining: 2m 21s
# 401:	total: 35.7s	remaining: 2m 21s
# 402:	total: 35.7s	remaining: 2m 21s
# 403:	total: 35.8s	remaining: 2m 21s
# 404:	total: 35.9s	remaining: 2m 21s
# 405:	total: 36s	remaining: 2m 21s
# 406:	total: 36s	remaining: 2m 21s
# 407:	total: 36.1s	remaining: 2m 20s
# 408:	total: 36.2s	remaining: 2m 20s
# 409:	total: 36.3s	remaining: 2m 20s
# 410:	total: 36.4s	remaining: 2m 20s
# 411:	total: 36.5s	remaining: 2m 20s
# 412:	total: 36.5s	remaining: 2m 20s
# 413:	total: 36.6s	remaining: 2m 20s
# 414:	total: 36.7s	remaining: 2m 20s
# 415:	total: 36.8s	remaining: 2m 20s
# 416:	total: 36.9s	remaining: 2m 19s
# 417:	total: 37s	remaining: 2m 19s
# 418:	total: 37s	remaining: 2m 19s
# 419:	total: 37.1s	remaining: 2m 19s
# 420:	total: 37.2s	remaining: 2m 19s
# 421:	total: 37.3s	remaining: 2m 19s
# 422:	total: 37.4s	remaining: 2m 19s
# 423:	total: 37.5s	remaining: 2m 19s
# 424:	total: 37.5s	remaining: 2m 19s
# 425:	total: 37.6s	remaining: 2m 18s
# 426:	total: 37.7s	remaining: 2m 18s
# 427:	total: 37.8s	remaining: 2m 18s
# 428:	total: 37.8s	remaining: 2m 18s
# 429:	total: 37.9s	remaining: 2m 18s
# 430:	total: 38s	remaining: 2m 18s
# 431:	total: 38.1s	remaining: 2m 18s
# 432:	total: 38.2s	remaining: 2m 18s
# 433:	total: 38.3s	remaining: 2m 18s
# 434:	total: 38.3s	remaining: 2m 17s
# 435:	total: 38.4s	remaining: 2m 17s
# 436:	total: 38.5s	remaining: 2m 17s
# 437:	total: 38.6s	remaining: 2m 17s
# 438:	total: 38.7s	remaining: 2m 17s
# 439:	total: 38.8s	remaining: 2m 17s
# 440:	total: 38.8s	remaining: 2m 17s
# 441:	total: 38.9s	remaining: 2m 17s
# 442:	total: 39s	remaining: 2m 17s
# 443:	total: 39.1s	remaining: 2m 17s
# 444:	total: 39.3s	remaining: 2m 17s
# 445:	total: 39.5s	remaining: 2m 17s
# 446:	total: 39.7s	remaining: 2m 17s
# 447:	total: 39.8s	remaining: 2m 17s
# 448:	total: 39.8s	remaining: 2m 17s
# 449:	total: 39.9s	remaining: 2m 17s
# 450:	total: 40s	remaining: 2m 17s
# 451:	total: 40.1s	remaining: 2m 17s
# 452:	total: 40.2s	remaining: 2m 17s
# 453:	total: 40.2s	remaining: 2m 17s
# 454:	total: 40.3s	remaining: 2m 16s
# 455:	total: 40.4s	remaining: 2m 16s
# 456:	total: 40.5s	remaining: 2m 16s
# 457:	total: 40.6s	remaining: 2m 16s
# 458:	total: 40.6s	remaining: 2m 16s
# 459:	total: 40.7s	remaining: 2m 16s
# 460:	total: 40.8s	remaining: 2m 16s
# 461:	total: 40.9s	remaining: 2m 16s
# 462:	total: 41s	remaining: 2m 16s
# 463:	total: 41.1s	remaining: 2m 15s
# 464:	total: 41.1s	remaining: 2m 15s
# 465:	total: 41.2s	remaining: 2m 15s
# 466:	total: 41.3s	remaining: 2m 15s
# 467:	total: 41.4s	remaining: 2m 15s
# 468:	total: 41.4s	remaining: 2m 15s
# 469:	total: 41.5s	remaining: 2m 15s
# 470:	total: 41.6s	remaining: 2m 15s
# 471:	total: 41.7s	remaining: 2m 14s
# 472:	total: 41.8s	remaining: 2m 14s
# 473:	total: 41.9s	remaining: 2m 14s
# 474:	total: 41.9s	remaining: 2m 14s
# 475:	total: 42s	remaining: 2m 14s
# 476:	total: 42.1s	remaining: 2m 14s
# 477:	total: 42.2s	remaining: 2m 14s
# 478:	total: 42.3s	remaining: 2m 14s
# 479:	total: 42.3s	remaining: 2m 14s
# 480:	total: 42.4s	remaining: 2m 13s
# 481:	total: 42.5s	remaining: 2m 13s
# 482:	total: 42.6s	remaining: 2m 13s
# 483:	total: 42.7s	remaining: 2m 13s
# 484:	total: 42.7s	remaining: 2m 13s
# 485:	total: 42.8s	remaining: 2m 13s
# 486:	total: 42.9s	remaining: 2m 13s
# 487:	total: 43s	remaining: 2m 13s
# 488:	total: 43.1s	remaining: 2m 13s
# 489:	total: 43.2s	remaining: 2m 13s
# 490:	total: 43.2s	remaining: 2m 12s
# 491:	total: 43.3s	remaining: 2m 12s
# 492:	total: 43.4s	remaining: 2m 12s
# 493:	total: 43.5s	remaining: 2m 12s
# 494:	total: 43.6s	remaining: 2m 12s
# 495:	total: 43.6s	remaining: 2m 12s
# 496:	total: 43.7s	remaining: 2m 12s
# 497:	total: 43.8s	remaining: 2m 12s
# 498:	total: 43.9s	remaining: 2m 11s
# 499:	total: 44s	remaining: 2m 11s
# 500:	total: 44s	remaining: 2m 11s
# 501:	total: 44.2s	remaining: 2m 11s
# 502:	total: 44.2s	remaining: 2m 11s
# 503:	total: 44.3s	remaining: 2m 11s
# 504:	total: 44.4s	remaining: 2m 11s
# 505:	total: 44.5s	remaining: 2m 11s
# 506:	total: 44.6s	remaining: 2m 11s
# 507:	total: 44.6s	remaining: 2m 11s
# 508:	total: 44.7s	remaining: 2m 10s
# 509:	total: 44.8s	remaining: 2m 10s
# 510:	total: 44.9s	remaining: 2m 10s
# 511:	total: 44.9s	remaining: 2m 10s
# 512:	total: 45s	remaining: 2m 10s
# 513:	total: 45.1s	remaining: 2m 10s
# 514:	total: 45.2s	remaining: 2m 10s
# 515:	total: 45.3s	remaining: 2m 10s
# 516:	total: 45.3s	remaining: 2m 10s
# 517:	total: 45.4s	remaining: 2m 9s
# 518:	total: 45.5s	remaining: 2m 9s
# 519:	total: 45.6s	remaining: 2m 9s
# 520:	total: 45.7s	remaining: 2m 9s
# 521:	total: 45.7s	remaining: 2m 9s
# 522:	total: 45.8s	remaining: 2m 9s
# 523:	total: 45.9s	remaining: 2m 9s
# 524:	total: 46s	remaining: 2m 9s
# 525:	total: 46.1s	remaining: 2m 9s
# 526:	total: 46.1s	remaining: 2m 8s
# 527:	total: 46.2s	remaining: 2m 8s
# 528:	total: 46.3s	remaining: 2m 8s
# 529:	total: 46.4s	remaining: 2m 8s
# 530:	total: 46.5s	remaining: 2m 8s
# 531:	total: 46.5s	remaining: 2m 8s
# 532:	total: 46.6s	remaining: 2m 8s
# 533:	total: 46.7s	remaining: 2m 8s
# 534:	total: 46.8s	remaining: 2m 8s
# 535:	total: 46.9s	remaining: 2m 7s
# 536:	total: 46.9s	remaining: 2m 7s
# 537:	total: 47s	remaining: 2m 7s
# 538:	total: 47.1s	remaining: 2m 7s
# 539:	total: 47.2s	remaining: 2m 7s
# 540:	total: 47.3s	remaining: 2m 7s
# 541:	total: 47.4s	remaining: 2m 7s
# 542:	total: 47.4s	remaining: 2m 7s
# 543:	total: 47.5s	remaining: 2m 7s
# 544:	total: 47.6s	remaining: 2m 7s
# 545:	total: 47.7s	remaining: 2m 6s
# 546:	total: 47.8s	remaining: 2m 6s
# 547:	total: 47.8s	remaining: 2m 6s
# 548:	total: 47.9s	remaining: 2m 6s
# 549:	total: 48s	remaining: 2m 6s
# 550:	total: 48.1s	remaining: 2m 6s
# 551:	total: 48.2s	remaining: 2m 6s
# 552:	total: 48.3s	remaining: 2m 6s
# 553:	total: 48.3s	remaining: 2m 6s
# 554:	total: 48.4s	remaining: 2m 6s
# 555:	total: 48.5s	remaining: 2m 6s
# 556:	total: 48.6s	remaining: 2m 5s
# 557:	total: 48.7s	remaining: 2m 5s
# 558:	total: 48.8s	remaining: 2m 5s
# 559:	total: 48.9s	remaining: 2m 5s
# 560:	total: 48.9s	remaining: 2m 5s
# 561:	total: 49s	remaining: 2m 5s
# 562:	total: 49.1s	remaining: 2m 5s
# 563:	total: 49.2s	remaining: 2m 5s
# 564:	total: 49.3s	remaining: 2m 5s
# 565:	total: 49.3s	remaining: 2m 4s
# 566:	total: 49.4s	remaining: 2m 4s
# 567:	total: 49.5s	remaining: 2m 4s
# 568:	total: 49.6s	remaining: 2m 4s
# 569:	total: 49.7s	remaining: 2m 4s
# 570:	total: 49.7s	remaining: 2m 4s
# 571:	total: 49.8s	remaining: 2m 4s
# 572:	total: 49.9s	remaining: 2m 4s
# 573:	total: 50s	remaining: 2m 4s
# 574:	total: 50.2s	remaining: 2m 4s
# 575:	total: 50.4s	remaining: 2m 4s
# 576:	total: 50.5s	remaining: 2m 4s
# 577:	total: 50.7s	remaining: 2m 4s
# 578:	total: 51s	remaining: 2m 5s
# 579:	total: 51.1s	remaining: 2m 5s
# 580:	total: 51.3s	remaining: 2m 5s
# 581:	total: 51.5s	remaining: 2m 5s
# 582:	total: 51.6s	remaining: 2m 5s
# 583:	total: 51.8s	remaining: 2m 5s
# 584:	total: 51.9s	remaining: 2m 5s
# 585:	total: 52s	remaining: 2m 5s
# 586:	total: 52.1s	remaining: 2m 5s
# 587:	total: 52.2s	remaining: 2m 5s
# 588:	total: 52.2s	remaining: 2m 5s
# 589:	total: 52.3s	remaining: 2m 5s
# 590:	total: 52.4s	remaining: 2m 4s
# 591:	total: 52.5s	remaining: 2m 4s
# 592:	total: 52.6s	remaining: 2m 4s
# 593:	total: 52.6s	remaining: 2m 4s
# 594:	total: 52.7s	remaining: 2m 4s
# 595:	total: 52.8s	remaining: 2m 4s
# 596:	total: 52.9s	remaining: 2m 4s
# 597:	total: 52.9s	remaining: 2m 4s
# 598:	total: 53s	remaining: 2m 4s
# 599:	total: 53.1s	remaining: 2m 3s
# 600:	total: 53.2s	remaining: 2m 3s
# 601:	total: 53.3s	remaining: 2m 3s
# 602:	total: 53.3s	remaining: 2m 3s
# 603:	total: 53.4s	remaining: 2m 3s
# 604:	total: 53.5s	remaining: 2m 3s
# 605:	total: 53.6s	remaining: 2m 3s
# 606:	total: 53.7s	remaining: 2m 3s
# 607:	total: 53.7s	remaining: 2m 3s
# 608:	total: 53.8s	remaining: 2m 2s
# 609:	total: 53.9s	remaining: 2m 2s
# 610:	total: 54s	remaining: 2m 2s
# 611:	total: 54.1s	remaining: 2m 2s
# 612:	total: 54.2s	remaining: 2m 2s
# 613:	total: 54.2s	remaining: 2m 2s
# 614:	total: 54.3s	remaining: 2m 2s
# 615:	total: 54.4s	remaining: 2m 2s
# 616:	total: 54.5s	remaining: 2m 2s
# 617:	total: 54.6s	remaining: 2m 2s
# 618:	total: 54.6s	remaining: 2m 1s
# 619:	total: 54.7s	remaining: 2m 1s
# 620:	total: 54.8s	remaining: 2m 1s
# 621:	total: 54.9s	remaining: 2m 1s
# 622:	total: 55s	remaining: 2m 1s
# 623:	total: 55s	remaining: 2m 1s
# 624:	total: 55.1s	remaining: 2m 1s
# 625:	total: 55.2s	remaining: 2m 1s
# 626:	total: 55.3s	remaining: 2m 1s
# 627:	total: 55.3s	remaining: 2m
# 628:	total: 55.4s	remaining: 2m
# 629:	total: 55.5s	remaining: 2m
# 630:	total: 55.6s	remaining: 2m
# 631:	total: 55.7s	remaining: 2m
# 632:	total: 55.8s	remaining: 2m
# 633:	total: 55.8s	remaining: 2m
# 634:	total: 55.9s	remaining: 2m
# 635:	total: 56s	remaining: 2m
# 636:	total: 56.1s	remaining: 2m
# 637:	total: 56.2s	remaining: 1m 59s
# 638:	total: 56.3s	remaining: 1m 59s
# 639:	total: 56.3s	remaining: 1m 59s
# 640:	total: 56.4s	remaining: 1m 59s
# 641:	total: 56.5s	remaining: 1m 59s
# 642:	total: 56.6s	remaining: 1m 59s
# 643:	total: 56.6s	remaining: 1m 59s
# 644:	total: 56.7s	remaining: 1m 59s
# 645:	total: 56.8s	remaining: 1m 59s
# 646:	total: 56.9s	remaining: 1m 58s
# 647:	total: 57s	remaining: 1m 58s
# 648:	total: 57.1s	remaining: 1m 58s
# 649:	total: 57.1s	remaining: 1m 58s
# 650:	total: 57.2s	remaining: 1m 58s
# 651:	total: 57.3s	remaining: 1m 58s
# 652:	total: 57.4s	remaining: 1m 58s
# 653:	total: 57.5s	remaining: 1m 58s
# 654:	total: 57.5s	remaining: 1m 58s
# 655:	total: 57.6s	remaining: 1m 58s
# 656:	total: 57.7s	remaining: 1m 57s
# 657:	total: 57.8s	remaining: 1m 57s
# 658:	total: 57.9s	remaining: 1m 57s
# 659:	total: 57.9s	remaining: 1m 57s
# 660:	total: 58s	remaining: 1m 57s
# 661:	total: 58.1s	remaining: 1m 57s
# 662:	total: 58.2s	remaining: 1m 57s
# 663:	total: 58.2s	remaining: 1m 57s
# 664:	total: 58.3s	remaining: 1m 57s
# 665:	total: 58.4s	remaining: 1m 56s
# 666:	total: 58.5s	remaining: 1m 56s
# 667:	total: 58.6s	remaining: 1m 56s
# 668:	total: 58.6s	remaining: 1m 56s
# 669:	total: 58.7s	remaining: 1m 56s
# 670:	total: 58.8s	remaining: 1m 56s
# 671:	total: 58.9s	remaining: 1m 56s
# 672:	total: 59s	remaining: 1m 56s
# 673:	total: 59.1s	remaining: 1m 56s
# 674:	total: 59.1s	remaining: 1m 56s
# 675:	total: 59.2s	remaining: 1m 55s
# 676:	total: 59.3s	remaining: 1m 55s
# 677:	total: 59.4s	remaining: 1m 55s
# 678:	total: 59.5s	remaining: 1m 55s
# 679:	total: 59.6s	remaining: 1m 55s
# 680:	total: 59.6s	remaining: 1m 55s
# 681:	total: 59.7s	remaining: 1m 55s
# 682:	total: 59.8s	remaining: 1m 55s
# 683:	total: 59.9s	remaining: 1m 55s
# 684:	total: 59.9s	remaining: 1m 55s
# 685:	total: 1m	remaining: 1m 54s
# 686:	total: 1m	remaining: 1m 54s
# 687:	total: 1m	remaining: 1m 54s
# 688:	total: 1m	remaining: 1m 54s
# 689:	total: 1m	remaining: 1m 54s
# 690:	total: 1m	remaining: 1m 54s
# 691:	total: 1m	remaining: 1m 54s
# 692:	total: 1m	remaining: 1m 54s
# 693:	total: 1m	remaining: 1m 54s
# 694:	total: 1m	remaining: 1m 54s
# 695:	total: 1m	remaining: 1m 53s
# 696:	total: 1m	remaining: 1m 53s
# 697:	total: 1m 1s	remaining: 1m 53s
# 698:	total: 1m 1s	remaining: 1m 53s
# 699:	total: 1m 1s	remaining: 1m 53s
# 700:	total: 1m 1s	remaining: 1m 53s
# 701:	total: 1m 1s	remaining: 1m 54s
# 702:	total: 1m 1s	remaining: 1m 53s
# 703:	total: 1m 1s	remaining: 1m 53s
# 704:	total: 1m 1s	remaining: 1m 53s
# 705:	total: 1m 2s	remaining: 1m 53s
# 706:	total: 1m 2s	remaining: 1m 53s
# 707:	total: 1m 2s	remaining: 1m 53s
# 708:	total: 1m 2s	remaining: 1m 53s
# 709:	total: 1m 2s	remaining: 1m 53s
# 710:	total: 1m 2s	remaining: 1m 53s
# 711:	total: 1m 2s	remaining: 1m 53s
# 712:	total: 1m 2s	remaining: 1m 52s
# 713:	total: 1m 2s	remaining: 1m 52s
# 714:	total: 1m 2s	remaining: 1m 52s
# 715:	total: 1m 2s	remaining: 1m 52s
# 716:	total: 1m 2s	remaining: 1m 52s
# 717:	total: 1m 2s	remaining: 1m 52s
# 718:	total: 1m 3s	remaining: 1m 52s
# 719:	total: 1m 3s	remaining: 1m 52s
# 720:	total: 1m 3s	remaining: 1m 52s
# 721:	total: 1m 3s	remaining: 1m 52s
# 722:	total: 1m 3s	remaining: 1m 51s
# 723:	total: 1m 3s	remaining: 1m 51s
# 724:	total: 1m 3s	remaining: 1m 51s
# 725:	total: 1m 3s	remaining: 1m 51s
# 726:	total: 1m 3s	remaining: 1m 51s
# 727:	total: 1m 3s	remaining: 1m 51s
# 728:	total: 1m 3s	remaining: 1m 51s
# 729:	total: 1m 3s	remaining: 1m 51s
# 730:	total: 1m 4s	remaining: 1m 51s
# 731:	total: 1m 4s	remaining: 1m 51s
# 732:	total: 1m 4s	remaining: 1m 51s
# 733:	total: 1m 4s	remaining: 1m 50s
# 734:	total: 1m 4s	remaining: 1m 50s
# 735:	total: 1m 4s	remaining: 1m 50s
# 736:	total: 1m 4s	remaining: 1m 50s
# 737:	total: 1m 4s	remaining: 1m 50s
# 738:	total: 1m 4s	remaining: 1m 50s
# 739:	total: 1m 4s	remaining: 1m 50s
# 740:	total: 1m 4s	remaining: 1m 50s
# 741:	total: 1m 4s	remaining: 1m 50s
# 742:	total: 1m 5s	remaining: 1m 49s
# 743:	total: 1m 5s	remaining: 1m 49s
# 744:	total: 1m 5s	remaining: 1m 49s
# 745:	total: 1m 5s	remaining: 1m 49s
# 746:	total: 1m 5s	remaining: 1m 49s
# 747:	total: 1m 5s	remaining: 1m 49s
# 748:	total: 1m 5s	remaining: 1m 49s
# 749:	total: 1m 5s	remaining: 1m 49s
# 750:	total: 1m 5s	remaining: 1m 49s
# 751:	total: 1m 5s	remaining: 1m 49s
# 752:	total: 1m 5s	remaining: 1m 48s
# 753:	total: 1m 5s	remaining: 1m 48s
# 754:	total: 1m 5s	remaining: 1m 48s
# 755:	total: 1m 6s	remaining: 1m 48s
# 756:	total: 1m 6s	remaining: 1m 48s
# 757:	total: 1m 6s	remaining: 1m 48s
# 758:	total: 1m 6s	remaining: 1m 48s
# 759:	total: 1m 6s	remaining: 1m 48s
# 760:	total: 1m 6s	remaining: 1m 48s
# 761:	total: 1m 6s	remaining: 1m 48s
# 762:	total: 1m 6s	remaining: 1m 47s
# 763:	total: 1m 6s	remaining: 1m 47s
# 764:	total: 1m 6s	remaining: 1m 47s
# 765:	total: 1m 6s	remaining: 1m 47s
# 766:	total: 1m 6s	remaining: 1m 47s
# 767:	total: 1m 7s	remaining: 1m 47s
# 768:	total: 1m 7s	remaining: 1m 47s
# 769:	total: 1m 7s	remaining: 1m 47s
# 770:	total: 1m 7s	remaining: 1m 47s
# 771:	total: 1m 7s	remaining: 1m 47s
# 772:	total: 1m 7s	remaining: 1m 47s
# 773:	total: 1m 7s	remaining: 1m 46s
# 774:	total: 1m 7s	remaining: 1m 46s
# 775:	total: 1m 7s	remaining: 1m 46s
# 776:	total: 1m 7s	remaining: 1m 46s
# 777:	total: 1m 7s	remaining: 1m 46s
# 778:	total: 1m 7s	remaining: 1m 46s
# 779:	total: 1m 8s	remaining: 1m 46s
# 780:	total: 1m 8s	remaining: 1m 46s
# 781:	total: 1m 8s	remaining: 1m 46s
# 782:	total: 1m 8s	remaining: 1m 46s
# 783:	total: 1m 8s	remaining: 1m 45s
# 784:	total: 1m 8s	remaining: 1m 45s
# 785:	total: 1m 8s	remaining: 1m 45s
# 786:	total: 1m 8s	remaining: 1m 45s
# 787:	total: 1m 8s	remaining: 1m 45s
# 788:	total: 1m 8s	remaining: 1m 45s
# 789:	total: 1m 8s	remaining: 1m 45s
# 790:	total: 1m 8s	remaining: 1m 45s
# 791:	total: 1m 8s	remaining: 1m 45s
# 792:	total: 1m 9s	remaining: 1m 45s
# 793:	total: 1m 9s	remaining: 1m 45s
# 794:	total: 1m 9s	remaining: 1m 44s
# 795:	total: 1m 9s	remaining: 1m 44s
# 796:	total: 1m 9s	remaining: 1m 44s
# 797:	total: 1m 9s	remaining: 1m 44s
# 798:	total: 1m 9s	remaining: 1m 44s
# 799:	total: 1m 9s	remaining: 1m 44s
# 800:	total: 1m 9s	remaining: 1m 44s
# 801:	total: 1m 9s	remaining: 1m 44s
# 802:	total: 1m 9s	remaining: 1m 44s
# 803:	total: 1m 9s	remaining: 1m 44s
# 804:	total: 1m 10s	remaining: 1m 43s
# 805:	total: 1m 10s	remaining: 1m 43s
# 806:	total: 1m 10s	remaining: 1m 43s
# 807:	total: 1m 10s	remaining: 1m 43s
# 808:	total: 1m 10s	remaining: 1m 43s
# 809:	total: 1m 10s	remaining: 1m 43s
# 810:	total: 1m 10s	remaining: 1m 43s
# 811:	total: 1m 10s	remaining: 1m 43s
# 812:	total: 1m 10s	remaining: 1m 43s
# 813:	total: 1m 10s	remaining: 1m 43s
# 814:	total: 1m 10s	remaining: 1m 43s
# 815:	total: 1m 10s	remaining: 1m 42s
# 816:	total: 1m 11s	remaining: 1m 42s
# 817:	total: 1m 11s	remaining: 1m 42s
# 818:	total: 1m 11s	remaining: 1m 42s
# 819:	total: 1m 11s	remaining: 1m 42s
# 820:	total: 1m 11s	remaining: 1m 42s
# 821:	total: 1m 11s	remaining: 1m 42s
# 822:	total: 1m 11s	remaining: 1m 42s
# 823:	total: 1m 11s	remaining: 1m 42s
# 824:	total: 1m 11s	remaining: 1m 42s
# 825:	total: 1m 11s	remaining: 1m 41s
# 826:	total: 1m 11s	remaining: 1m 41s
# 827:	total: 1m 11s	remaining: 1m 41s
# 828:	total: 1m 12s	remaining: 1m 41s
# 829:	total: 1m 12s	remaining: 1m 41s
# 830:	total: 1m 12s	remaining: 1m 41s
# 831:	total: 1m 12s	remaining: 1m 41s
# 832:	total: 1m 12s	remaining: 1m 41s
# 833:	total: 1m 12s	remaining: 1m 41s
# 834:	total: 1m 12s	remaining: 1m 41s
# 835:	total: 1m 12s	remaining: 1m 41s
# 836:	total: 1m 13s	remaining: 1m 41s
# 837:	total: 1m 13s	remaining: 1m 41s
# 838:	total: 1m 13s	remaining: 1m 41s
# 839:	total: 1m 13s	remaining: 1m 41s
# 840:	total: 1m 13s	remaining: 1m 41s
# 841:	total: 1m 13s	remaining: 1m 40s
# 842:	total: 1m 13s	remaining: 1m 40s
# 843:	total: 1m 13s	remaining: 1m 40s
# 844:	total: 1m 13s	remaining: 1m 40s
# 845:	total: 1m 13s	remaining: 1m 40s
# 846:	total: 1m 13s	remaining: 1m 40s
# 847:	total: 1m 13s	remaining: 1m 40s
# 848:	total: 1m 14s	remaining: 1m 40s
# 849:	total: 1m 14s	remaining: 1m 40s
# 850:	total: 1m 14s	remaining: 1m 40s
# 851:	total: 1m 14s	remaining: 1m 40s
# 852:	total: 1m 14s	remaining: 1m 39s
# 853:	total: 1m 14s	remaining: 1m 39s
# 854:	total: 1m 14s	remaining: 1m 39s
# 855:	total: 1m 14s	remaining: 1m 39s
# 856:	total: 1m 14s	remaining: 1m 39s
# 857:	total: 1m 14s	remaining: 1m 39s
# 858:	total: 1m 14s	remaining: 1m 39s
# 859:	total: 1m 14s	remaining: 1m 39s
# 860:	total: 1m 14s	remaining: 1m 39s
# 861:	total: 1m 15s	remaining: 1m 39s
# 862:	total: 1m 15s	remaining: 1m 39s
# 863:	total: 1m 15s	remaining: 1m 38s
# 864:	total: 1m 15s	remaining: 1m 38s
# 865:	total: 1m 15s	remaining: 1m 38s
# 866:	total: 1m 15s	remaining: 1m 38s
# 867:	total: 1m 15s	remaining: 1m 38s
# 868:	total: 1m 15s	remaining: 1m 38s
# 869:	total: 1m 15s	remaining: 1m 38s
# 870:	total: 1m 15s	remaining: 1m 38s
# 871:	total: 1m 15s	remaining: 1m 38s
# 872:	total: 1m 15s	remaining: 1m 38s
# 873:	total: 1m 16s	remaining: 1m 37s
# 874:	total: 1m 16s	remaining: 1m 37s
# 875:	total: 1m 16s	remaining: 1m 37s
# 876:	total: 1m 16s	remaining: 1m 37s
# 877:	total: 1m 16s	remaining: 1m 37s
# 878:	total: 1m 16s	remaining: 1m 37s
# 879:	total: 1m 16s	remaining: 1m 37s
# 880:	total: 1m 16s	remaining: 1m 37s
# 881:	total: 1m 16s	remaining: 1m 37s
# 882:	total: 1m 16s	remaining: 1m 37s
# 883:	total: 1m 16s	remaining: 1m 37s
# 884:	total: 1m 16s	remaining: 1m 36s
# 885:	total: 1m 17s	remaining: 1m 36s
# 886:	total: 1m 17s	remaining: 1m 36s
# 887:	total: 1m 17s	remaining: 1m 36s
# 888:	total: 1m 17s	remaining: 1m 36s
# 889:	total: 1m 17s	remaining: 1m 36s
# 890:	total: 1m 17s	remaining: 1m 36s
# 891:	total: 1m 17s	remaining: 1m 36s
# 892:	total: 1m 17s	remaining: 1m 36s
# 893:	total: 1m 17s	remaining: 1m 36s
# 894:	total: 1m 17s	remaining: 1m 36s
# 895:	total: 1m 17s	remaining: 1m 35s
# 896:	total: 1m 17s	remaining: 1m 35s
# 897:	total: 1m 18s	remaining: 1m 35s
# 898:	total: 1m 18s	remaining: 1m 35s
# 899:	total: 1m 18s	remaining: 1m 35s
# 900:	total: 1m 18s	remaining: 1m 35s
# 901:	total: 1m 18s	remaining: 1m 35s
# 902:	total: 1m 18s	remaining: 1m 35s
# 903:	total: 1m 18s	remaining: 1m 35s
# 904:	total: 1m 18s	remaining: 1m 35s
# 905:	total: 1m 18s	remaining: 1m 35s
# 906:	total: 1m 18s	remaining: 1m 34s
# 907:	total: 1m 18s	remaining: 1m 34s
# 908:	total: 1m 18s	remaining: 1m 34s
# 909:	total: 1m 18s	remaining: 1m 34s
# 910:	total: 1m 19s	remaining: 1m 34s
# 911:	total: 1m 19s	remaining: 1m 34s
# 912:	total: 1m 19s	remaining: 1m 34s
# 913:	total: 1m 19s	remaining: 1m 34s
# 914:	total: 1m 19s	remaining: 1m 34s
# 915:	total: 1m 19s	remaining: 1m 34s
# 916:	total: 1m 19s	remaining: 1m 33s
# 917:	total: 1m 19s	remaining: 1m 33s
# 918:	total: 1m 19s	remaining: 1m 33s
# 919:	total: 1m 19s	remaining: 1m 33s
# 920:	total: 1m 19s	remaining: 1m 33s
# 921:	total: 1m 19s	remaining: 1m 33s
# 922:	total: 1m 20s	remaining: 1m 33s
# ...
# 1566:	total: 2m 15s	remaining: 37.5s
# 1567:	total: 2m 15s	remaining: 37.5s
# 1568:	total: 2m 16s	remaining: 37.4s
# 1569:	total: 2m 16s	remaining: 37.3s
# 1570:	total: 2m 16s	remaining: 37.2s
# 1571:	total: 2m 16s	remaining: 37.1s
# 1572:	total: 2m 16s	remaining: 37s
# 1573:	total: 2m 16s	remaining: 36.9s
# 1574:	total: 2m 16s	remaining: 36.8s
# 1575:	total: 2m 16s	remaining: 36.7s
# 1576:	total: 2m 16s	remaining: 36.7s
# 1577:	total: 2m 16s	remaining: 36.6s
# 1578:	total: 2m 16s	remaining: 36.5s
# 1579:	total: 2m 16s	remaining: 36.4s
# 1580:	total: 2m 17s	remaining: 36.3s
# 1581:	total: 2m 17s	remaining: 36.2s
# 1582:	total: 2m 17s	remaining: 36.1s
# 1583:	total: 2m 17s	remaining: 36s
# 1584:	total: 2m 17s	remaining: 36s
# 1585:	total: 2m 17s	remaining: 35.9s
# 1586:	total: 2m 17s	remaining: 35.8s
# 1587:	total: 2m 17s	remaining: 35.7s
# 1588:	total: 2m 17s	remaining: 35.6s
# 1589:	total: 2m 17s	remaining: 35.5s
# 1590:	total: 2m 17s	remaining: 35.5s
# 1591:	total: 2m 18s	remaining: 35.4s
# 1592:	total: 2m 18s	remaining: 35.3s
# 1593:	total: 2m 18s	remaining: 35.2s
# 1594:	total: 2m 18s	remaining: 35.2s
# 1595:	total: 2m 18s	remaining: 35.1s
# 1596:	total: 2m 18s	remaining: 35s
# 1597:	total: 2m 18s	remaining: 34.9s
# 1598:	total: 2m 18s	remaining: 34.8s
# 1599:	total: 2m 18s	remaining: 34.7s
# 1600:	total: 2m 19s	remaining: 34.6s
# 1601:	total: 2m 19s	remaining: 34.6s
# 1602:	total: 2m 19s	remaining: 34.5s
# 1603:	total: 2m 19s	remaining: 34.4s
# 1604:	total: 2m 19s	remaining: 34.3s
# 1605:	total: 2m 19s	remaining: 34.2s
# 1606:	total: 2m 19s	remaining: 34.1s
# 1607:	total: 2m 19s	remaining: 34s
# 1608:	total: 2m 19s	remaining: 33.9s
# 1609:	total: 2m 19s	remaining: 33.8s
# 1610:	total: 2m 19s	remaining: 33.8s
# 1611:	total: 2m 19s	remaining: 33.7s
# 1612:	total: 2m 19s	remaining: 33.6s
# 1613:	total: 2m 20s	remaining: 33.5s
# 1614:	total: 2m 20s	remaining: 33.4s
# 1615:	total: 2m 20s	remaining: 33.3s
# 1616:	total: 2m 20s	remaining: 33.2s
# 1617:	total: 2m 20s	remaining: 33.1s
# 1618:	total: 2m 20s	remaining: 33.1s
# 1619:	total: 2m 20s	remaining: 33s
# 1620:	total: 2m 20s	remaining: 32.9s
# 1621:	total: 2m 20s	remaining: 32.8s
# 1622:	total: 2m 20s	remaining: 32.7s
# 1623:	total: 2m 20s	remaining: 32.6s
# 1624:	total: 2m 20s	remaining: 32.5s
# 1625:	total: 2m 21s	remaining: 32.4s
# 1626:	total: 2m 21s	remaining: 32.4s
# 1627:	total: 2m 21s	remaining: 32.3s
# 1628:	total: 2m 21s	remaining: 32.2s
# 1629:	total: 2m 21s	remaining: 32.1s
# 1630:	total: 2m 21s	remaining: 32s
# 1631:	total: 2m 21s	remaining: 31.9s
# 1632:	total: 2m 21s	remaining: 31.8s
# 1633:	total: 2m 21s	remaining: 31.7s
# 1634:	total: 2m 21s	remaining: 31.6s
# 1635:	total: 2m 21s	remaining: 31.6s
# 1636:	total: 2m 21s	remaining: 31.5s
# 1637:	total: 2m 22s	remaining: 31.4s
# 1638:	total: 2m 22s	remaining: 31.3s
# 1639:	total: 2m 22s	remaining: 31.2s
# 1640:	total: 2m 22s	remaining: 31.1s
# 1641:	total: 2m 22s	remaining: 31s
# 1642:	total: 2m 22s	remaining: 30.9s
# 1643:	total: 2m 22s	remaining: 30.9s
# 1644:	total: 2m 22s	remaining: 30.8s
# 1645:	total: 2m 22s	remaining: 30.7s
# 1646:	total: 2m 22s	remaining: 30.6s
# 1647:	total: 2m 22s	remaining: 30.5s
# 1648:	total: 2m 22s	remaining: 30.4s
# 1649:	total: 2m 22s	remaining: 30.3s
# 1650:	total: 2m 23s	remaining: 30.2s
# 1651:	total: 2m 23s	remaining: 30.2s
# 1652:	total: 2m 23s	remaining: 30.1s
# 1653:	total: 2m 23s	remaining: 30s
# 1654:	total: 2m 23s	remaining: 29.9s
# 1655:	total: 2m 23s	remaining: 29.8s
# 1656:	total: 2m 23s	remaining: 29.7s
# 1657:	total: 2m 23s	remaining: 29.6s
# 1658:	total: 2m 23s	remaining: 29.5s
# 1659:	total: 2m 23s	remaining: 29.5s
# 1660:	total: 2m 23s	remaining: 29.4s
# 1661:	total: 2m 23s	remaining: 29.3s
# 1662:	total: 2m 24s	remaining: 29.2s
# 1663:	total: 2m 24s	remaining: 29.1s
# 1664:	total: 2m 24s	remaining: 29s
# 1665:	total: 2m 24s	remaining: 28.9s
# 1666:	total: 2m 24s	remaining: 28.8s
# 1667:	total: 2m 24s	remaining: 28.8s
# 1668:	total: 2m 24s	remaining: 28.7s
# 1669:	total: 2m 24s	remaining: 28.6s
# 1670:	total: 2m 24s	remaining: 28.5s
# 1671:	total: 2m 24s	remaining: 28.4s
# 1672:	total: 2m 24s	remaining: 28.3s
# 1673:	total: 2m 24s	remaining: 28.2s
# 1674:	total: 2m 25s	remaining: 28.1s
# 1675:	total: 2m 25s	remaining: 28.1s
# 1676:	total: 2m 25s	remaining: 28s
# 1677:	total: 2m 25s	remaining: 27.9s
# 1678:	total: 2m 25s	remaining: 27.8s
# 1679:	total: 2m 25s	remaining: 27.7s
# 1680:	total: 2m 25s	remaining: 27.6s
# 1681:	total: 2m 25s	remaining: 27.5s
# 1682:	total: 2m 25s	remaining: 27.4s
# 1683:	total: 2m 25s	remaining: 27.4s
# 1684:	total: 2m 25s	remaining: 27.3s
# 1685:	total: 2m 25s	remaining: 27.2s
# 1686:	total: 2m 26s	remaining: 27.1s
# 1687:	total: 2m 26s	remaining: 27s
# 1688:	total: 2m 26s	remaining: 26.9s
# 1689:	total: 2m 26s	remaining: 26.8s
# 1690:	total: 2m 26s	remaining: 26.7s
# 1691:	total: 2m 26s	remaining: 26.7s
# 1692:	total: 2m 26s	remaining: 26.6s
# 1693:	total: 2m 26s	remaining: 26.5s
# 1694:	total: 2m 26s	remaining: 26.4s
# 1695:	total: 2m 26s	remaining: 26.3s
# 1696:	total: 2m 26s	remaining: 26.2s
# 1697:	total: 2m 26s	remaining: 26.1s
# 1698:	total: 2m 27s	remaining: 26s
# 1699:	total: 2m 27s	remaining: 26s
# 1700:	total: 2m 27s	remaining: 25.9s
# 1701:	total: 2m 27s	remaining: 25.8s
# 1702:	total: 2m 27s	remaining: 25.7s
# 1703:	total: 2m 27s	remaining: 25.6s
# 1704:	total: 2m 27s	remaining: 25.5s
# 1705:	total: 2m 27s	remaining: 25.4s
# 1706:	total: 2m 27s	remaining: 25.3s
# 1707:	total: 2m 27s	remaining: 25.3s
# 1708:	total: 2m 27s	remaining: 25.2s
# 1709:	total: 2m 27s	remaining: 25.1s
# 1710:	total: 2m 28s	remaining: 25s
# 1711:	total: 2m 28s	remaining: 24.9s
# 1712:	total: 2m 28s	remaining: 24.8s
# 1713:	total: 2m 28s	remaining: 24.7s
# 1714:	total: 2m 28s	remaining: 24.7s
# 1715:	total: 2m 28s	remaining: 24.6s
# 1716:	total: 2m 28s	remaining: 24.5s
# 1717:	total: 2m 28s	remaining: 24.4s
# 1718:	total: 2m 29s	remaining: 24.4s
# 1719:	total: 2m 29s	remaining: 24.3s
# 1720:	total: 2m 29s	remaining: 24.3s
# 1721:	total: 2m 29s	remaining: 24.2s
# 1722:	total: 2m 29s	remaining: 24.1s
# 1723:	total: 2m 30s	remaining: 24s
# 1724:	total: 2m 30s	remaining: 23.9s
# 1725:	total: 2m 30s	remaining: 23.8s
# 1726:	total: 2m 30s	remaining: 23.8s
# 1727:	total: 2m 30s	remaining: 23.7s
# 1728:	total: 2m 30s	remaining: 23.6s
# 1729:	total: 2m 30s	remaining: 23.5s
# 1730:	total: 2m 30s	remaining: 23.4s
# 1731:	total: 2m 30s	remaining: 23.3s
# 1732:	total: 2m 30s	remaining: 23.2s
# 1733:	total: 2m 30s	remaining: 23.1s
# 1734:	total: 2m 30s	remaining: 23.1s
# 1735:	total: 2m 31s	remaining: 23s
# 1736:	total: 2m 31s	remaining: 22.9s
# 1737:	total: 2m 31s	remaining: 22.8s
# 1738:	total: 2m 31s	remaining: 22.7s
# 1739:	total: 2m 31s	remaining: 22.6s
# 1740:	total: 2m 31s	remaining: 22.5s
# 1741:	total: 2m 31s	remaining: 22.4s
# 1742:	total: 2m 31s	remaining: 22.4s
# 1743:	total: 2m 31s	remaining: 22.3s
# 1744:	total: 2m 31s	remaining: 22.2s
# 1745:	total: 2m 31s	remaining: 22.1s
# 1746:	total: 2m 31s	remaining: 22s
# 1747:	total: 2m 32s	remaining: 21.9s
# 1748:	total: 2m 32s	remaining: 21.8s
# 1749:	total: 2m 32s	remaining: 21.7s
# 1750:	total: 2m 32s	remaining: 21.7s
# 1751:	total: 2m 32s	remaining: 21.6s
# 1752:	total: 2m 32s	remaining: 21.5s
# 1753:	total: 2m 32s	remaining: 21.4s
# 1754:	total: 2m 32s	remaining: 21.3s
# 1755:	total: 2m 32s	remaining: 21.2s
# 1756:	total: 2m 32s	remaining: 21.1s
# 1757:	total: 2m 32s	remaining: 21s
# 1758:	total: 2m 32s	remaining: 21s
# 1759:	total: 2m 33s	remaining: 20.9s
# 1760:	total: 2m 33s	remaining: 20.8s
# 1761:	total: 2m 33s	remaining: 20.7s
# 1762:	total: 2m 33s	remaining: 20.6s
# 1763:	total: 2m 33s	remaining: 20.5s
# 1764:	total: 2m 33s	remaining: 20.4s
# 1765:	total: 2m 33s	remaining: 20.3s
# 1766:	total: 2m 33s	remaining: 20.3s
# 1767:	total: 2m 33s	remaining: 20.2s
# 1768:	total: 2m 33s	remaining: 20.1s
# 1769:	total: 2m 33s	remaining: 20s
# 1770:	total: 2m 33s	remaining: 19.9s
# 1771:	total: 2m 33s	remaining: 19.8s
# 1772:	total: 2m 34s	remaining: 19.7s
# 1773:	total: 2m 34s	remaining: 19.6s
# 1774:	total: 2m 34s	remaining: 19.6s
# 1775:	total: 2m 34s	remaining: 19.5s
# 1776:	total: 2m 34s	remaining: 19.4s
# 1777:	total: 2m 34s	remaining: 19.3s
# 1778:	total: 2m 34s	remaining: 19.2s
# 1779:	total: 2m 34s	remaining: 19.1s
# 1780:	total: 2m 34s	remaining: 19s
# 1781:	total: 2m 34s	remaining: 18.9s
# 1782:	total: 2m 34s	remaining: 18.9s
# 1783:	total: 2m 34s	remaining: 18.8s
# 1784:	total: 2m 35s	remaining: 18.7s
# 1785:	total: 2m 35s	remaining: 18.6s
# 1786:	total: 2m 35s	remaining: 18.5s
# 1787:	total: 2m 35s	remaining: 18.4s
# 1788:	total: 2m 35s	remaining: 18.3s
# 1789:	total: 2m 35s	remaining: 18.2s
# 1790:	total: 2m 35s	remaining: 18.1s
# 1791:	total: 2m 35s	remaining: 18.1s
# 1792:	total: 2m 35s	remaining: 18s
# 1793:	total: 2m 35s	remaining: 17.9s
# 1794:	total: 2m 35s	remaining: 17.8s
# 1795:	total: 2m 35s	remaining: 17.7s
# 1796:	total: 2m 36s	remaining: 17.6s
# 1797:	total: 2m 36s	remaining: 17.5s
# 1798:	total: 2m 36s	remaining: 17.4s
# 1799:	total: 2m 36s	remaining: 17.4s
# 1800:	total: 2m 36s	remaining: 17.3s
# 1801:	total: 2m 36s	remaining: 17.2s
# 1802:	total: 2m 36s	remaining: 17.1s
# 1803:	total: 2m 36s	remaining: 17s
# 1804:	total: 2m 36s	remaining: 16.9s
# 1805:	total: 2m 36s	remaining: 16.8s
# 1806:	total: 2m 36s	remaining: 16.7s
# 1807:	total: 2m 36s	remaining: 16.7s
# 1808:	total: 2m 36s	remaining: 16.6s
# 1809:	total: 2m 37s	remaining: 16.5s
# 1810:	total: 2m 37s	remaining: 16.4s
# 1811:	total: 2m 37s	remaining: 16.3s
# 1812:	total: 2m 37s	remaining: 16.2s
# 1813:	total: 2m 37s	remaining: 16.1s
# 1814:	total: 2m 37s	remaining: 16s
# 1815:	total: 2m 37s	remaining: 16s
# 1816:	total: 2m 37s	remaining: 15.9s
# 1817:	total: 2m 37s	remaining: 15.8s
# 1818:	total: 2m 37s	remaining: 15.7s
# 1819:	total: 2m 37s	remaining: 15.6s
# 1820:	total: 2m 37s	remaining: 15.5s
# 1821:	total: 2m 38s	remaining: 15.4s
# 1822:	total: 2m 38s	remaining: 15.4s
# 1823:	total: 2m 38s	remaining: 15.3s
# 1824:	total: 2m 38s	remaining: 15.2s
# 1825:	total: 2m 38s	remaining: 15.1s
# 1826:	total: 2m 38s	remaining: 15s
# 1827:	total: 2m 38s	remaining: 14.9s
# 1828:	total: 2m 38s	remaining: 14.8s
# 1829:	total: 2m 38s	remaining: 14.7s
# 1830:	total: 2m 38s	remaining: 14.7s
# 1831:	total: 2m 38s	remaining: 14.6s
# 1832:	total: 2m 38s	remaining: 14.5s
# 1833:	total: 2m 39s	remaining: 14.4s
# 1834:	total: 2m 39s	remaining: 14.3s
# 1835:	total: 2m 39s	remaining: 14.2s
# 1836:	total: 2m 39s	remaining: 14.1s
# 1837:	total: 2m 39s	remaining: 14s
# 1838:	total: 2m 39s	remaining: 14s
# 1839:	total: 2m 39s	remaining: 13.9s
# 1840:	total: 2m 39s	remaining: 13.8s
# 1841:	total: 2m 39s	remaining: 13.7s
# 1842:	total: 2m 39s	remaining: 13.6s
# 1843:	total: 2m 39s	remaining: 13.5s
# 1844:	total: 2m 40s	remaining: 13.5s
# 1845:	total: 2m 40s	remaining: 13.4s
# 1846:	total: 2m 40s	remaining: 13.3s
# 1847:	total: 2m 40s	remaining: 13.2s
# 1848:	total: 2m 40s	remaining: 13.1s
# 1849:	total: 2m 40s	remaining: 13s
# 1850:	total: 2m 40s	remaining: 12.9s
# 1851:	total: 2m 40s	remaining: 12.9s
# 1852:	total: 2m 40s	remaining: 12.8s
# 1853:	total: 2m 41s	remaining: 12.7s
# 1854:	total: 2m 41s	remaining: 12.6s
# 1855:	total: 2m 41s	remaining: 12.5s
# 1856:	total: 2m 41s	remaining: 12.4s
# 1857:	total: 2m 41s	remaining: 12.3s
# 1858:	total: 2m 41s	remaining: 12.2s
# 1859:	total: 2m 41s	remaining: 12.2s
# 1860:	total: 2m 41s	remaining: 12.1s
# 1861:	total: 2m 41s	remaining: 12s
# 1862:	total: 2m 41s	remaining: 11.9s
# 1863:	total: 2m 41s	remaining: 11.8s
# 1864:	total: 2m 41s	remaining: 11.7s
# 1865:	total: 2m 42s	remaining: 11.6s
# 1866:	total: 2m 42s	remaining: 11.5s
# 1867:	total: 2m 42s	remaining: 11.5s
# 1868:	total: 2m 42s	remaining: 11.4s
# 1869:	total: 2m 42s	remaining: 11.3s
# 1870:	total: 2m 42s	remaining: 11.2s
# 1871:	total: 2m 42s	remaining: 11.1s
# 1872:	total: 2m 42s	remaining: 11s
# 1873:	total: 2m 42s	remaining: 10.9s
# 1874:	total: 2m 42s	remaining: 10.8s
# 1875:	total: 2m 42s	remaining: 10.8s
# 1876:	total: 2m 42s	remaining: 10.7s
# 1877:	total: 2m 43s	remaining: 10.6s
# 1878:	total: 2m 43s	remaining: 10.5s
# 1879:	total: 2m 43s	remaining: 10.4s
# 1880:	total: 2m 43s	remaining: 10.3s
# 1881:	total: 2m 43s	remaining: 10.2s
# 1882:	total: 2m 43s	remaining: 10.2s
# 1883:	total: 2m 43s	remaining: 10.1s
# 1884:	total: 2m 43s	remaining: 9.98s
# 1885:	total: 2m 43s	remaining: 9.89s
# 1886:	total: 2m 43s	remaining: 9.8s
# 1887:	total: 2m 43s	remaining: 9.72s
# 1888:	total: 2m 43s	remaining: 9.63s
# 1889:	total: 2m 43s	remaining: 9.54s
# 1890:	total: 2m 44s	remaining: 9.46s
# 1891:	total: 2m 44s	remaining: 9.37s
# 1892:	total: 2m 44s	remaining: 9.28s
# 1893:	total: 2m 44s	remaining: 9.2s
# 1894:	total: 2m 44s	remaining: 9.11s
# 1895:	total: 2m 44s	remaining: 9.02s
# 1896:	total: 2m 44s	remaining: 8.93s
# 1897:	total: 2m 44s	remaining: 8.85s
# 1898:	total: 2m 44s	remaining: 8.76s
# 1899:	total: 2m 44s	remaining: 8.67s
# 1900:	total: 2m 44s	remaining: 8.59s
# 1901:	total: 2m 44s	remaining: 8.5s
# 1902:	total: 2m 45s	remaining: 8.41s
# 1903:	total: 2m 45s	remaining: 8.32s
# 1904:	total: 2m 45s	remaining: 8.24s
# 1905:	total: 2m 45s	remaining: 8.15s
# 1906:	total: 2m 45s	remaining: 8.06s
# 1907:	total: 2m 45s	remaining: 7.97s
# 1908:	total: 2m 45s	remaining: 7.89s
# 1909:	total: 2m 45s	remaining: 7.8s
# 1910:	total: 2m 45s	remaining: 7.71s
# 1911:	total: 2m 45s	remaining: 7.63s
# 1912:	total: 2m 45s	remaining: 7.54s
# 1913:	total: 2m 45s	remaining: 7.45s
# 1914:	total: 2m 45s	remaining: 7.37s
# 1915:	total: 2m 46s	remaining: 7.28s
# 1916:	total: 2m 46s	remaining: 7.19s
# 1917:	total: 2m 46s	remaining: 7.11s
# 1918:	total: 2m 46s	remaining: 7.02s
# 1919:	total: 2m 46s	remaining: 6.93s
# 1920:	total: 2m 46s	remaining: 6.84s
# 1921:	total: 2m 46s	remaining: 6.76s
# 1922:	total: 2m 46s	remaining: 6.67s
# 1923:	total: 2m 46s	remaining: 6.58s
# 1924:	total: 2m 46s	remaining: 6.5s
# 1925:	total: 2m 46s	remaining: 6.41s
# 1926:	total: 2m 46s	remaining: 6.32s
# 1927:	total: 2m 47s	remaining: 6.24s
# 1928:	total: 2m 47s	remaining: 6.15s
# 1929:	total: 2m 47s	remaining: 6.06s
# 1930:	total: 2m 47s	remaining: 5.98s
# 1931:	total: 2m 47s	remaining: 5.89s
# 1932:	total: 2m 47s	remaining: 5.8s
# 1933:	total: 2m 47s	remaining: 5.72s
# 1934:	total: 2m 47s	remaining: 5.63s
# 1935:	total: 2m 47s	remaining: 5.54s
# 1936:	total: 2m 47s	remaining: 5.46s
# 1937:	total: 2m 47s	remaining: 5.37s
# 1938:	total: 2m 47s	remaining: 5.28s
# 1939:	total: 2m 47s	remaining: 5.2s
# 1940:	total: 2m 48s	remaining: 5.11s
# 1941:	total: 2m 48s	remaining: 5.02s
# 1942:	total: 2m 48s	remaining: 4.93s
# 1943:	total: 2m 48s	remaining: 4.85s
# 1944:	total: 2m 48s	remaining: 4.76s
# 1945:	total: 2m 48s	remaining: 4.67s
# 1946:	total: 2m 48s	remaining: 4.59s
# 1947:	total: 2m 48s	remaining: 4.5s
# 1948:	total: 2m 48s	remaining: 4.41s
# 1949:	total: 2m 48s	remaining: 4.33s
# 1950:	total: 2m 48s	remaining: 4.24s
# 1951:	total: 2m 48s	remaining: 4.15s
# 1952:	total: 2m 49s	remaining: 4.07s
# 1953:	total: 2m 49s	remaining: 3.98s
# 1954:	total: 2m 49s	remaining: 3.89s
# 1955:	total: 2m 49s	remaining: 3.81s
# 1956:	total: 2m 49s	remaining: 3.72s
# 1957:	total: 2m 49s	remaining: 3.63s
# 1958:	total: 2m 49s	remaining: 3.55s
# 1959:	total: 2m 49s	remaining: 3.46s
# 1960:	total: 2m 49s	remaining: 3.37s
# 1961:	total: 2m 49s	remaining: 3.29s
# 1962:	total: 2m 49s	remaining: 3.2s
# 1963:	total: 2m 49s	remaining: 3.11s
# 1964:	total: 2m 50s	remaining: 3.03s
# 1965:	total: 2m 50s	remaining: 2.94s
# 1966:	total: 2m 50s	remaining: 2.85s
# 1967:	total: 2m 50s	remaining: 2.77s
# 1968:	total: 2m 50s	remaining: 2.68s
# 1969:	total: 2m 50s	remaining: 2.6s
# 1970:	total: 2m 50s	remaining: 2.51s
# 1971:	total: 2m 50s	remaining: 2.42s
# 1972:	total: 2m 50s	remaining: 2.33s
# 1973:	total: 2m 50s	remaining: 2.25s
# 1974:	total: 2m 51s	remaining: 2.16s
# 1975:	total: 2m 51s	remaining: 2.08s
# 1976:	total: 2m 51s	remaining: 1.99s
# 1977:	total: 2m 51s	remaining: 1.91s
# 1978:	total: 2m 51s	remaining: 1.82s
# 1979:	total: 2m 51s	remaining: 1.73s
# 1980:	total: 2m 51s	remaining: 1.65s
# 1981:	total: 2m 51s	remaining: 1.56s
# 1982:	total: 2m 51s	remaining: 1.47s
# 1983:	total: 2m 51s	remaining: 1.39s
# 1984:	total: 2m 52s	remaining: 1.3s
# 1985:	total: 2m 52s	remaining: 1.21s
# 1986:	total: 2m 52s	remaining: 1.13s
# 1987:	total: 2m 52s	remaining: 1.04s
# 1988:	total: 2m 52s	remaining: 953ms
# 1989:	total: 2m 52s	remaining: 867ms
# 1990:	total: 2m 52s	remaining: 780ms
# 1991:	total: 2m 52s	remaining: 693ms
# 1992:	total: 2m 52s	remaining: 606ms
# 1993:	total: 2m 52s	remaining: 520ms
# 1994:	total: 2m 52s	remaining: 433ms
# 1995:	total: 2m 52s	remaining: 347ms
# 1996:	total: 2m 52s	remaining: 260ms
# 1997:	total: 2m 53s	remaining: 173ms
# 1998:	total: 2m 53s	remaining: 86.6ms
# 1999:	total: 2m 53s	remaining: 0us

# %%
y_pred=model.predict(X_test)
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
from sklearn.metrics import roc_auc_score
print(roc_auc_score(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     85164
#            1       0.99      1.00      1.00     85425
#
#     accuracy                           1.00    170589
#    macro avg       1.00      1.00      1.00    170589
# weighted avg       1.00      1.00      1.00    170589
#
# 0.9967415809496971

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(model,X_test,y_test)

# %%
plot_feature_importance(model.get_feature_importance(),X_train.columns,'CATBOOST')
